# %% [markdown]
# ## Importing neccessary libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import re
import json
# Out:
# C:\Users\shuto\AppData\Local\Temp\ipykernel_11224\3342817584.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Full scraping script

# %%
url = "https://www.vhis.gov.hk/en/consumer_corner/flexi-plan.html"
driver = webdriver.Chrome()
driver.get(url)

# latest_date = driver.find_element(By.CLASS_NAME, 'table-body-item--plan-date-no').find_element(By.TAG_NAME, "span")
# print(latest_date.text.strip())
data = {
    'plan': {
        'plan_name': [],
        'insurer': [],
        'effective_date': [],
        'earliest_date': []
    },
    'certifications': []
}
# plan contains information of each plan container
plans = driver.find_elements(By.CLASS_NAME, 'table-body-wrapper')

# name of plan
for plan in plans:
    plan_name = plan.find_element(By.CSS_SELECTOR, 'div.table-body-item--plan')
    plan_name = plan_name.find_elements(By.TAG_NAME, 'span')[0].text
    plan_name = re.sub(r'\n', '', plan_name)

    # Append the plan name to the list within the dictionary
    data['plan']['plan_name'].extend([plan_name])
    # print(plan_name)


# company Information
for company in plans:
    company_name = company.find_element(By.CSS_SELECTOR, 'div.table-body-item--offer-company')
    company_name = company_name.find_elements(By.TAG_NAME, "span")[1].text
    data['plan']['insurer'].extend([company_name])

# effective date information
for effective_date in plans:
    effective_date_details = effective_date.find_elements(By.CLASS_NAME, 'table-body-item')[2]
    effective_date = effective_date_details.find_elements(By.CSS_SELECTOR, 'span')[1].text
    data['plan']['effective_date'].extend([effective_date])

# earliest date information
for earliest_date in plans:
    try:
        earliest_date_details = earliest_date.find_elements(By.CLASS_NAME, 'table-body-item')[2]
        _earliest_date = earliest_date_details.find_element(By.CSS_SELECTOR, 'i').text
        _earliest_date = re.sub(r'\n', '', _earliest_date)
        _earliest_date = re.sub(r'Earliest version:', '', _earliest_date)
    except:
        _earliest_date = ''
    data['plan']['earliest_date'].append(_earliest_date)

# certifications information
for cert in plans:
    cert_details = cert.find_elements(By.CLASS_NAME, 'table-body-item')[3]
    cert_no = cert_details.find_elements(By.CSS_SELECTOR, 'div.cert-level a')
    cert_data = {
    "cert_no": [],
    "ward_level":[],
    "plan_premium":[]
    }
    for index, cert in enumerate(cert_no):
        if index % 2 == 0:
            cert_data['ward_level'].append(cert.text)
        else:
            cert_data["plan_premium"].append(cert.text)

    parent_divs = cert_details.find_elements(By.CSS_SELECTOR, 'div.cert-level')

    # Loop through each parent div element
    for parent_div in parent_divs:
        desired_text = parent_div.find_element(By.CSS_SELECTOR, 'span').text.strip()
        cert_data["cert_no"].append(desired_text)
        
    data['certifications'].append(cert_data)


print(json.dumps(data, indent= 4))
print(json.dumps(cert_data, indent = 4))
# all length is 63
# print(len(data['plan']['name_of_certified_flexi_plan']))
# print(len(data['plan']['name_of_offering_company']))
# print(len(data['plan']['earliest_date']))
# print(len(data['plan']['effective_date']))
driver.quit()
# Out:
# {
#     "plan": {
#         "plan_name": [
#             "AIA Voluntary Health Insurance Flexi Scheme",
#             "AIA Voluntary Health Insurance Prime Scheme",
#             "AIA Voluntary Health Insurance Privilege Scheme",
#             "AIA Voluntary Health Insurance Privilege Plus Scheme",
#             "AIA Voluntary Health Insurance Privilege Ultra Scheme",
#             "Allianz Ultra Medical Protect##The insurance company offering this Certified Plan has ceased to maintain its registration as a VHIS Provider from 1 July 2022. Upon the effective date of de-registration, only renewals are available for existing policies of this Certified Plan. Also, there will not be further updates of relevant product and premium on this webpage thereafter. Please contact the insurance company for the latest updates of the Certified Plan.*Supplement on value-added tax & goods and services tax",
#             "Asia Elite",
#             "Asia iCare",
#             "AXA WiseGuard Pro Medical Insurance Plan",
#             "Smart Medicare",
#             "Smart Medicare",
#             "BOC Flexi Voluntary Health Insurance Scheme Certified Plan",
#             "Blue Cross Dynasty VHIS Plan",
#             "Blue Cross Love Yourself VHIS Plan",
#             "CareForYou Flexi Plan for VHIS",
#             "CareForYou Super Flexi Plan for VHIS",
#             "SmartViva Flexi VHIS",
#             "Bowtie Pink VHIS Plan",
#             "Bowtie VHIS Flexi",
#             "Bupa Hero VHIS Plan",
#             "Bupa MyFlexi VHIS Plan",
#             "Global Prestige VHIS Plan",
#             "Healthy Life Medical Insurance Plan",
#             "Healthy Life Premier Medical Insurance Plan",
#             "Taiping Life VHIS Flexi Plan",
#             "Taiping Life VHIS Priority Plan",
#             "Chubb VHIS - Flexi Plan",
#             "Chubb VHIS - Prime Plan",
#             "VHIS Series - Flexi Plan (SMM)(Formerly known as ''Cigna VHIS Series - Flexi Plan (SMM)'')",
#             "VHIS Series - Flexi Plan (Superior)(Formerly known as ''Cigna VHIS Series - Flexi Plan (Superior)'')",
#             "Cigna VHIS Series - Flexi Plan (SMM)",
#             "Cigna VHIS Series - Flexi Plan (Superior)",
#             "''BetterCare'' Medical Insurance Plan",
#             "''FlexiCare'' Medical Insurance Plan",
#             "''TopCare'' Medical Insurance Plan",
#             "vBooster Medical Plan",
#             "vCANsurance Medical Plan",
#             "vCare Medical Plan",
#             "vCare Supreme Medical Plan",
#             "vFamily Medical Plan",
#             "vPrime Medical Plan",
#             "vPrime Signature Medical Plan",
#             "vTheOne Medical Plan",
#             "Health Supreme Medical Plan",
#             "HSBC Voluntary Health Insurance Flexi Plan",
#             "Liberty Insurance VHIS Series - Flexi Plan (Classic)",
#             "Liberty Insurance VHIS Series - Flexi Plan (Plus)",
#             "Liberty Insurance VHIS Series - Flexi Plan (Premium)",
#             "Manulife First VHIS Flexi Plan",
#             "Manulife Supreme Lite VHIS Supplementary Benefit",
#             "Manulife Supreme VHIS Flexi Plan",
#             "VHIS Prestige Care",
#             "PRUHealth FlexiChoice Medical Plan",
#             "PRUHealth VHIS EasyChoice Plan",
#             "PRUHealth VHIS VIP Plan",
#             "WeHealth Plus",
#             "WeHealth Preferred",
#             "WeHealth Prestige",
#             "Well Protect Voluntary Health Insurance Scheme (Flexi)",
#             "TaxVantage Plus Medical Plan",
#             "TaxVantage Prestige Medical Plan",
#             "HealthFlexi Plus Voluntary Health Insurance Plan",
#             "HealthFlexi Voluntary Health Insurance Plan"
#         ],
#         "insurer": [
#             "AIA International Limited",
#             "AIA International Limited",
#             "AIA International Limited",
#             "AIA International Limited",
#             "AIA International Limited",
#             "Allianz Global Corporate & Specialty SE",
#             "Asia Insurance Company, Limited",
#             "Asia Insurance Company, Limited",
#             "AXA China Region Insurance Company (Bermuda) Limited",
#             "AXA China Region Insurance Company (Bermuda) Limited",
#             "AXA China Region Insurance Company Limited",
#             "Bank of China Group Insurance Company Limited",
#             "Blue Cross (Asia-Pacific) Insurance Limited",
#             "Blue Cross (Asia-Pacific) Insurance Limited",
#             "Blue Cross (Asia-Pacific) Insurance Limited",
#             "Blue Cross (Asia-Pacific) Insurance Limited",
#             "BOC Group Life Assurance Company Limited",
#             "Bowtie Life Insurance Company Limited",
#             "Bowtie Life Insurance Company Limited",
#             "Bupa (Asia) Limited",
#             "Bupa (Asia) Limited",
#             "Bupa (Asia) Limited",
#             "China Life Insurance (Overseas) Company Limited",
#             "China Life Insurance (Overseas) Company Limited",
#             "China Taiping Life Insurance (Hong Kong) Company Limited",
#             "China Taiping Life Insurance (Hong Kong) Company Limited",
#             "Chubb Life Insurance Hong Kong Limited\n(Formerly underwritten by ''Chubb Life Insurance Company Ltd.'')",
#             "Chubb Life Insurance Hong Kong Limited",
#             "Chubb Life Insurance Hong Kong Limited\n(Formerly known as ''Cigna Worldwide Life Insurance Company Limited'')",
#             "Chubb Life Insurance Hong Kong Limited\n(Formerly known as ''Cigna Worldwide Life Insurance Company Limited'')",
#             "CIGNA Worldwide General Insurance Company Limited",
#             "CIGNA Worldwide General Insurance Company Limited",
#             "FTLife Insurance Company Limited",
#             "FTLife Insurance Company Limited",
#             "FTLife Insurance Company Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "FWD Life Insurance Company (Bermuda) Limited",
#             "Hong Kong Life Insurance Limited",
#             "HSBC Life (International) Limited",
#             "Liberty International Insurance Limited",
#             "Liberty International Insurance Limited",
#             "Liberty International Insurance Limited",
#             "Manulife (International) Limited",
#             "Manulife (International) Limited",
#             "Manulife (International) Limited",
#             "MSIG Insurance (Hong Kong) Limited",
#             "Prudential Hong Kong Limited",
#             "Prudential Hong Kong Limited",
#             "Prudential Hong Kong Limited",
#             "Sun Life Hong Kong Limited",
#             "Sun Life Hong Kong Limited",
#             "Sun Life Hong Kong Limited",
#             "Well Link Life Insurance Company Limited",
#             "YF Life Insurance International Limited",
#             "YF Life Insurance International Limited",
#             "Zurich Insurance Company Ltd",
#             "Zurich Insurance Company Ltd"
#         ],
#         "effective_date": [
#             "15 July 2023",
#             "22 April 2024",
#             "22 April 2024",
#             "22 April 2024",
#             "22 April 2024",
#             "1 April 2021",
#             "1 April 2021",
#             "22 November 2021",
#             "31 July 2023",
#             "31 July 2023",
#             "31 July 2023",
#             "1 April 2021",
#             "1 January 2024",
#             "15 March 2024",
#             "1 January 2024",
#             "1 January 2024",
#             "1 August 2022",
#             "7 December 2023",
#             "7 December 2023",
#             "2 March 2024",
#             "2 March 2024",
#             "2 December 2023",
#             "1 April 2021",
#             "1 April 2021",
#             "7 July 2021",
#             "1 January 2023",
#             "1 April 2024",
#             "16 April 2024",
#             "1 November 2022",
#             "1 November 2022",
#             "1 July 2023",
#             "1 July 2023",
#             "23 November 2023",
#             "16 May 2022",
#             "23 November 2023",
#             "9 January 2023",
#             "15 April 2024",
#             "1 August 2023",
#             "15 April 2024",
#             "4 March 2024",
#             "15 November 2023",
#             "9 October 2023",
#             "11 July 2022",
#             "12 October 2020",
#             "29 March 2021",
#             "1 July 2021",
#             "1 July 2021",
#             "1 July 2021",
#             "1 October 2022",
#             "6 November 2023",
#             "29 December 2023",
#             "1 April 2021",
#             "1 July 2023",
#             "3 October 2022",
#             "1 April 2023",
#             "1 April 2022",
#             "18 March 2022",
#             "21 January 2022",
#             "30 October 2020",
#             "1 January 2024",
#             "1 January 2024",
#             "19 March 2021",
#             "19 March 2021"
#         ],
#         "earliest_date": [
#             "1 April 2019",
#             "15 April 2019",
#             "22 February 2021",
#             "15 March 2021",
#             "",
#             "29 July 2019",
#             "2 October 2019",
#             "",
#             "25 July 2019",
#             "1 April 2019",
#             "1 April 2019",
#             "28 June 2019",
#             "16 August 2021",
#             "",
#             "1 April 2019",
#             "28 February 2020",
#             "26 July 2021",
#             "28 October 2021",
#             "8 July 2019",
#             "3 February 2020",
#             "24 May 2019",
#             "19 August 2019",
#             "1 April 2019",
#             "3 June 2019",
#             "20 January 2021",
#             "22 November 2021",
#             "14 May 2019",
#             "",
#             "24 March 2021",
#             "24 March 2021",
#             "1 April 2019",
#             "1 April 2019",
#             "1 April 2019",
#             "",
#             "30 August 2019",
#             "",
#             "12 October 2020",
#             "1 April 2019",
#             "22 July 2019",
#             "",
#             "1 May 2020",
#             "",
#             "",
#             "6 December 2019",
#             "20 July 2020",
#             "15 June 2020",
#             "15 June 2020",
#             "15 June 2020",
#             "1 April 2019",
#             "",
#             "17 February 2020",
#             "1 April 2019",
#             "1 April 2019",
#             "",
#             "3 September 2020",
#             "2 May 2019",
#             "",
#             "",
#             "6 February 2020",
#             "1 April 2019",
#             "18 February 2022",
#             "16 October 2019",
#             "6 August 2020"
#         ]
#     },
#     "certifications": [
#         {
#             "cert_no": [
#                 "F00022-01-000-03",
#                 "F00022-02-000-03",
#                 "F00022-03-000-03",
#                 "F00022-04-000-03",
#                 "F00022-05-000-03",
#                 "F00022-06-000-03"
#             ],
#             "ward_level": [
#                 "Ward (HKD)*",
#                 "Semi-private (HKD)*",
#                 "Standard Private (HKD)*",
#                 "Ward (USD)*",
#                 "Semi-private (USD)*",
#                 "Standard Private (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00025-01-000-03",
#                 "F00025-02-000-03",
#                 "F00025-03-000-03",
#                 "F00025-04-000-03",
#                 "F00025-05-000-03",
#                 "F00025-06-000-03"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD16,000 Deductible*",
#                 "HKD25,000 Deductible*",
#                 "USD0 Deductible*",
#                 "USD2,000 Deductible*",
#                 "USD3,125 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00053-01-000-02",
#                 "F00053-02-000-02",
#                 "F00053-03-000-02",
#                 "F00053-04-000-02",
#                 "F00053-05-000-02",
#                 "F00053-06-000-02"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD16,000 Deductible*",
#                 "HKD25,000 Deductible*",
#                 "USD0 Deductible*",
#                 "USD2,000 Deductible*",
#                 "USD3,125 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00054-01-000-02",
#                 "F00054-02-000-02",
#                 "F00054-03-000-02",
#                 "F00054-04-000-02",
#                 "F00054-05-000-02",
#                 "F00054-06-000-02"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD16,000 Deductible*",
#                 "HKD25,000 Deductible*",
#                 "USD0 Deductible*",
#                 "USD2,000 Deductible*",
#                 "USD3,125 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00074-01-000-01",
#                 "F00074-02-000-01",
#                 "F00074-03-000-01",
#                 "F00074-04-000-01",
#                 "F00074-05-000-01",
#                 "F00074-06-000-01",
#                 "F00074-07-000-01",
#                 "F00074-08-000-01",
#                 "F00074-09-000-01",
#                 "F00074-10-000-01",
#                 "F00074-11-000-01",
#                 "F00074-12-000-01",
#                 "F00074-13-000-01",
#                 "F00074-14-000-01",
#                 "F00074-15-000-01",
#                 "F00074-16-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia)*",
#                 "HKD16,000 Deductible (Asia)*",
#                 "HKD25,000 Deductible (Asia)*",
#                 "HKD50,000 Deductible (Asia)*",
#                 "HKD0 Deductible (Worldwide except USA)*",
#                 "HKD16,000 Deductible (Worldwide except USA)*",
#                 "HKD25,000 Deductible (Worldwide except USA)*",
#                 "HKD50,000 Deductible (Worldwide except USA)*",
#                 "USD0 Deductible (Asia)*",
#                 "USD2,000 Deductible (Asia)*",
#                 "USD3,125 Deductible (Asia)*",
#                 "USD6,250 Deductible (Asia)*",
#                 "USD0 Deductible (Worldwide except USA)*",
#                 "USD2,000 Deductible (Worldwide except USA)*",
#                 "USD3,125 Deductible (Worldwide except USA)*",
#                 "USD6,250 Deductible (Worldwide except USA)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00033-01-000-02",
#                 "F00033-01-001-02",
#                 "F00033-02-000-02",
#                 "F00033-02-001-02"
#             ],
#             "ward_level": [
#                 "Silver Plan*",
#                 "Silver Plan with SMM*",
#                 "Gold Plan*",
#                 "Gold Plan with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00038-01-000-02",
#                 "F00038-02-000-02"
#             ],
#             "ward_level": [
#                 "Semi-Private Room*",
#                 "Standard Private Room*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00061-01-000-01",
#                 "F00061-01-001-01",
#                 "F00061-02-000-01",
#                 "F00061-02-001-01",
#                 "F00061-02-002-01"
#             ],
#             "ward_level": [
#                 "Plan 1*",
#                 "Plan 1A with SMM*",
#                 "Plan 2*",
#                 "Plan 2A with SMM*",
#                 "Plan 2B with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00034-01-000-04",
#                 "F00034-02-000-04",
#                 "F00034-03-000-04",
#                 "F00034-04-000-04",
#                 "F00034-05-000-04",
#                 "F00034-06-000-04",
#                 "F00034-07-000-04",
#                 "F00034-08-000-04",
#                 "F00034-09-000-04",
#                 "F00034-10-000-04",
#                 "F00034-11-000-04",
#                 "F00034-12-000-04",
#                 "F00034-13-000-04",
#                 "F00034-14-000-04",
#                 "F00034-15-000-04",
#                 "F00034-16-000-04",
#                 "F00034-17-000-04",
#                 "F00034-18-000-04",
#                 "F00034-19-000-02",
#                 "F00034-20-000-02",
#                 "F00034-21-000-02",
#                 "F00034-22-000-02",
#                 "F00034-23-000-02",
#                 "F00034-24-000-02"
#             ],
#             "ward_level": [
#                 "Regular (HKD0 Deductible)*",
#                 "Regular (HKD20,000 Deductible)*",
#                 "Regular (HKD50,000 Deductible)*",
#                 "Enhance (HKD0 Deductible)*",
#                 "Enhance (HKD20,000 Deductible)*",
#                 "Enhance (HKD50,000 Deductible)*",
#                 "Premier (HKD0 Deductible)*",
#                 "Premier (HKD20,000 Deductible)*",
#                 "Premier (HKD50,000 Deductible)*",
#                 "Regular (USD0 Deductible)*",
#                 "Regular (USD2,500 Deductible)*",
#                 "Regular (USD6,250 Deductible)*",
#                 "Enhance (USD0 Deductible)*",
#                 "Enhance (USD2,500 Deductible)*",
#                 "Enhance (USD6,250 Deductible)*",
#                 "Premier (USD0 Deductible)*",
#                 "Premier (USD2,500 Deductible)*",
#                 "Premier (USD6,250 Deductible)*",
#                 "Noble (HKD0 Deductible)*",
#                 "Noble (HKD20,000 Deductible)*",
#                 "Noble (HKD50,000 Deductible)*",
#                 "Noble (USD0 Deductible)*",
#                 "Noble (USD2,500 Deductible)*",
#                 "Noble (USD6,250 Deductible)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00017-01-000-03",
#                 "F00017-01-001-03",
#                 "F00017-02-000-03",
#                 "F00017-02-001-03",
#                 "F00017-03-000-03",
#                 "F00017-03-001-03",
#                 "F00017-04-000-03",
#                 "F00017-04-001-03",
#                 "F00017-05-000-03",
#                 "F00017-05-001-03",
#                 "F00017-06-000-03",
#                 "F00017-06-001-03"
#             ],
#             "ward_level": [
#                 "Regular (HKD)*",
#                 "Regular with SMM (HKD)*",
#                 "Superior (HKD)*",
#                 "Superior with SMM (HKD)*",
#                 "Premier (HKD)*",
#                 "Premier with SMM (HKD)*",
#                 "Regular (USD)*",
#                 "Regular with SMM (USD)*",
#                 "Superior (USD)*",
#                 "Superior with SMM (USD)*",
#                 "Premier (USD)*",
#                 "Premier with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00018-01-000-03",
#                 "F00018-01-001-03",
#                 "F00018-02-000-03",
#                 "F00018-02-001-03",
#                 "F00018-03-000-03",
#                 "F00018-03-001-03",
#                 "F00018-04-000-03",
#                 "F00018-04-001-03",
#                 "F00018-05-000-03",
#                 "F00018-05-001-03",
#                 "F00018-06-000-03",
#                 "F00018-06-001-03"
#             ],
#             "ward_level": [
#                 "Regular (HKD)*",
#                 "Regular with SMM (HKD)*",
#                 "Superior (HKD)*",
#                 "Superior with SMM (HKD)*",
#                 "Premier (HKD)*",
#                 "Premier with SMM (HKD)*",
#                 "Regular (USD)*",
#                 "Regular with SMM (USD)*",
#                 "Superior (USD)*",
#                 "Superior with SMM (USD)*",
#                 "Premier (USD)*",
#                 "Premier with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00028-01-000-02",
#                 "F00028-01-001-02",
#                 "F00028-01-002-02",
#                 "F00028-01-003-02",
#                 "F00028-01-004-02",
#                 "F00028-01-005-02",
#                 "F00028-01-006-02",
#                 "F00028-01-007-02"
#             ],
#             "ward_level": [
#                 "Basic plan*",
#                 "Basic plan with upgraded benefits 1*",
#                 "Basic plan with upgraded benefits 2*",
#                 "Basic plan with upgraded benefits 3*",
#                 "Basic plan with SMM*",
#                 "Basic plan with SMM & upgraded benefits 1*",
#                 "Basic plan with SMM & upgraded benefits 2*",
#                 "Basic plan with SMM & upgraded benefits 3*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00059-01-000-01",
#                 "F00059-02-000-01",
#                 "F00059-03-000-01",
#                 "F00059-04-000-01",
#                 "F00059-05-000-01",
#                 "F00059-06-000-01",
#                 "F00059-07-000-01",
#                 "F00059-08-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD20,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD40,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD80,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD0 Deductible (Worldwide )*",
#                 "HKD20,000 Deductible (Worldwide )*",
#                 "HKD40,000 Deductible (Worldwide )*",
#                 "HKD80,000 Deductible (Worldwide )*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00073-01-000-01",
#                 "F00073-02-000-01",
#                 "F00073-03-000-01",
#                 "F00073-04-000-01",
#                 "F00073-05-000-01",
#                 "F00073-06-000-01",
#                 "F00073-07-000-01",
#                 "F00073-08-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD20,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD40,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD80,000 Deductible (Asia & Australia-New Zealand)*",
#                 "HKD0 Deductible (Worldwide )*",
#                 "HKD20,000 Deductible (Worldwide )*",
#                 "HKD40,000 Deductible (Worldwide )*",
#                 "HKD80,000 Deductible (Worldwide )*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00014-01-000-02"
#             ],
#             "ward_level": [
#                 "CareForYou*"
#             ],
#             "plan_premium": [
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00043-01-000-02",
#                 "F00043-01-001-02",
#                 "F00043-01-002-02",
#                 "F00043-02-000-02",
#                 "F00043-02-001-02",
#                 "F00043-02-002-02",
#                 "F00043-03-000-02",
#                 "F00043-03-001-02",
#                 "F00043-03-002-02",
#                 "F00043-04-000-02"
#             ],
#             "ward_level": [
#                 "Plan A*",
#                 "Plan A with SMM (No Coinsurance)*",
#                 "Plan A with SMM (with 20% Coinsurance)*",
#                 "Plan B*",
#                 "Plan B with SMM (No Coinsurance)*",
#                 "Plan B with SMM (with 20% Coinsurance)*",
#                 "Plan C*",
#                 "Plan C with SMM (No Coinsurance)*",
#                 "Plan C with SMM (with 20% Coinsurance)*",
#                 "Plan D with SMM (with 20% Coinsurance)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00057-01-000-02",
#                 "F00057-02-000-02",
#                 "F00057-03-000-02",
#                 "F00057-04-000-02"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD10,000 Deductible*",
#                 "HKD30,000 Deductible*",
#                 "HKD70,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00060-01-000-04",
#                 "F00060-02-000-04",
#                 "F00060-03-000-04",
#                 "F00060-04-000-04",
#                 "F00060-05-000-04",
#                 "F00060-06-000-04",
#                 "F00060-07-000-04",
#                 "F00060-08-000-04",
#                 "F00060-09-000-01",
#                 "F00060-10-000-01",
#                 "F00060-11-000-01",
#                 "F00060-12-000-01"
#             ],
#             "ward_level": [
#                 "Semi-Private Room - HKD0 Deductible*",
#                 "Semi-Private Room - HKD20,000 Deductible*",
#                 "Semi-Private Room - HKD50,000 Deductible*",
#                 "Semi-Private Room - HKD80,000 Deductible*",
#                 "Private Room - HKD0 Deductible*",
#                 "Private Room - HKD20,000 Deductible*",
#                 "Private Room - HKD50,000 Deductible*",
#                 "Private Room - HKD80,000 Deductible*",
#                 "Ward Room - HKD0 Deductible*",
#                 "Ward Room - HKD20,000 Deductible*",
#                 "Ward Room - HKD50,000 Deductible*",
#                 "Ward Room - HKD80,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00031-01-000-05",
#                 "F00031-02-000-05"
#             ],
#             "ward_level": [
#                 "Regular*",
#                 "Plus*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00040-01-000-03",
#                 "F00040-02-000-03",
#                 "F00040-03-000-03",
#                 "F00040-04-000-03",
#                 "F00040-05-000-03",
#                 "F00040-06-000-03",
#                 "F00040-07-000-03",
#                 "F00040-08-000-03",
#                 "F00040-09-000-01",
#                 "F00040-10-000-01",
#                 "F00040-11-000-01",
#                 "F00040-12-000-01",
#                 "F00040-13-000-01",
#                 "F00040-14-000-01",
#                 "F00040-15-000-01",
#                 "F00040-16-000-01"
#             ],
#             "ward_level": [
#                 "Advance (HKD0 Deductible)*",
#                 "Advance (HKD12,000 Deductible)*",
#                 "Advance (HKD40,000 Deductible)*",
#                 "Advance (HKD80,000 Deductible)*",
#                 "Deluxe (HKD0 Deductible)*",
#                 "Deluxe (HKD12,000 Deductible)*",
#                 "Deluxe (HKD40,000 Deductible)*",
#                 "Deluxe (HKD80,000 Deductible)*",
#                 "Advance Pro (HKD0 Deductible)*",
#                 "Advance Pro (HKD12,000 Deductible)*",
#                 "Advance Pro (HKD40,000 Deductible)*",
#                 "Advance Pro (HKD80,000 Deductible)*",
#                 "Deluxe Pro (HKD0 Deductible)*",
#                 "Deluxe Pro (HKD12,000 Deductible)*",
#                 "Deluxe Pro (HKD40,000 Deductible)*",
#                 "Deluxe Pro (HKD80,000 Deductible)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00029-01-000-05",
#                 "F00029-01-001-05",
#                 "F00029-02-000-05",
#                 "F00029-02-001-05",
#                 "F00029-03-000-05",
#                 "F00029-03-001-05"
#             ],
#             "ward_level": [
#                 "Standard*",
#                 "Standard Plus*",
#                 "Advance*",
#                 "Advance Plus*",
#                 "Deluxe*",
#                 "Deluxe Plus*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00035-01-000-04",
#                 "F00035-02-000-04",
#                 "F00035-03-000-04",
#                 "F00035-04-000-04"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD12,000 Deductible*",
#                 "HKD40,000 Deductible*",
#                 "HKD80,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00024-01-000-02"
#             ],
#             "ward_level": [
#                 "Healthy Life Medical Insurance Plan*"
#             ],
#             "plan_premium": [
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00030-01-000-02",
#                 "F00030-01-001-02",
#                 "F00030-02-000-02",
#                 "F00030-02-001-02"
#             ],
#             "ward_level": [
#                 "Semi-private*",
#                 "Semi-private with SMM*",
#                 "Private*",
#                 "Private with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00052-01-000-01",
#                 "F00052-02-000-01",
#                 "F00052-02-001-01",
#                 "F00052-03-000-01",
#                 "F00052-03-001-01"
#             ],
#             "ward_level": [
#                 "Plan 1 - Ward with SMM*",
#                 "Plan 2 - Semi-Private Room*",
#                 "Plan 3 - Semi-Private Room with SMM*",
#                 "Plan 4 - Standard Private Room*",
#                 "Plan 5 - Standard Private Room with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00062-01-000-02",
#                 "F00062-02-000-02",
#                 "F00062-03-000-02",
#                 "F00062-04-000-02",
#                 "F00062-05-000-02",
#                 "F00062-06-000-02"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD20,000 Deductible*",
#                 "HKD50,000 Deductible*",
#                 "USD0 Deductible*",
#                 "USD2,500 Deductible*",
#                 "USD6,250 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00027-01-000-03",
#                 "F00027-01-001-03",
#                 "F00027-02-000-03",
#                 "F00027-02-001-03",
#                 "F00027-03-000-03",
#                 "F00027-03-001-03",
#                 "F00027-04-000-03",
#                 "F00027-04-001-03",
#                 "F00027-05-000-03",
#                 "F00027-05-001-03",
#                 "F00027-06-000-03",
#                 "F00027-06-001-03",
#                 "F00027-07-000-03",
#                 "F00027-07-001-03",
#                 "F00027-08-000-03",
#                 "F00027-08-001-03"
#             ],
#             "ward_level": [
#                 "Classic (HKD)*",
#                 "Classic with Top-up benefit (HKD)*",
#                 "Ward (HKD)*",
#                 "Ward with Top-up benefit (HKD)*",
#                 "Semi-Private (HKD)*",
#                 "Semi-Private with Top-up benefit (HKD)*",
#                 "Private (HKD)*",
#                 "Private with Top-up benefit (HKD)*",
#                 "Classic (USD)*",
#                 "Classic with Top-up benefit (USD)*",
#                 "Ward (USD)*",
#                 "Ward with Top-up benefit (USD)*",
#                 "Semi-Private (USD)*",
#                 "Semi-Private with Top-up benefit (USD)*",
#                 "Private (USD)*",
#                 "Private with Top-up benefit (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00075-01-000-01",
#                 "F00075-02-000-01",
#                 "F00075-03-000-01",
#                 "F00075-04-000-01",
#                 "F00075-05-000-01",
#                 "F00075-06-000-01",
#                 "F00075-07-000-01",
#                 "F00075-08-000-01",
#                 "F00075-09-000-01",
#                 "F00075-10-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia)*",
#                 "HKD25,000 Deductible (Asia)*",
#                 "HKD50,000 Deductible (Asia)*",
#                 "HKD100,000 Deductible (Asia)*",
#                 "HKD150,000 Deductible (Asia)*",
#                 "HKD0 Deductible (Worldwide excluding USA)*",
#                 "HKD25,000 Deductible (Worldwide excluding USA)*",
#                 "HKD50,000 Deductible (Worldwide excluding USA)*",
#                 "HKD100,000 Deductible (Worldwide excluding USA)*",
#                 "HKD150,000 Deductible (Worldwide excluding USA)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00055-01-000-02"
#             ],
#             "ward_level": [
#                 "Flexi Plan SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00056-01-000-03",
#                 "F00056-02-000-03",
#                 "F00056-03-000-03",
#                 "F00056-04-000-03",
#                 "F00056-05-000-03",
#                 "F00056-06-000-02",
#                 "F00056-07-000-02",
#                 "F00056-08-000-02"
#             ],
#             "ward_level": [
#                 "Semi-Private Room - HKD0 Deductible*",
#                 "Semi-Private Room - HKD15,000 Deductible*",
#                 "Semi-Private Room - HKD25,000 Deductible*",
#                 "Semi-Private Room - HKD50,000 Deductible*",
#                 "Semi-Private Room - HKD75,000 Deductible*",
#                 "Standard Ward - HKD0 Deductible*",
#                 "Standard Ward - HKD15,000 Deductible*",
#                 "Standard Ward - HKD25,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00012-01-000-03"
#             ],
#             "ward_level": [
#                 "Flexi Plan SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00016-01-000-04",
#                 "F00016-02-000-04",
#                 "F00016-03-000-04",
#                 "F00016-04-000-04",
#                 "F00016-05-000-03",
#                 "F00016-06-000-02",
#                 "F00016-07-000-02",
#                 "F00016-08-000-02"
#             ],
#             "ward_level": [
#                 "Semi-Private Room - HKD0 Deductible*",
#                 "Semi-Private Room - HKD15,000 Deductible*",
#                 "Semi-Private Room - HKD25,000 Deductible*",
#                 "Semi-Private Room - HKD50,000 Deductible*",
#                 "Semi-Private Room - HKD75,000 Deductible*",
#                 "Standard Ward - HKD0 Deductible*",
#                 "Standard Ward - HKD15,000 Deductible*",
#                 "Standard Ward - HKD25,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00021-01-000-02",
#                 "F00021-02-000-02",
#                 "F00021-03-000-02",
#                 "F00021-04-000-02",
#                 "F00021-05-000-02",
#                 "F00021-06-000-02"
#             ],
#             "ward_level": [
#                 "Benefit Level 1 with SMM (HKD)*",
#                 "Benefit Level 2 with SMM (HKD)*",
#                 "Benefit Level 3 with SMM (HKD)*",
#                 "Benefit Level 1 with SMM (USD)*",
#                 "Benefit Level 2 with SMM (USD)*",
#                 "Benefit Level 3 with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00064-01-000-01",
#                 "F00064-02-000-01",
#                 "F00064-03-000-01",
#                 "F00064-04-000-01"
#             ],
#             "ward_level": [
#                 "Benefit Level 1 (HKD)*",
#                 "Benefit Level 2 (HKD)*",
#                 "Benefit Level 1 (USD)*",
#                 "Benefit Level 2 (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00037-01-000-02",
#                 "F00037-02-000-02",
#                 "F00037-03-000-02",
#                 "F00037-04-000-02",
#                 "F00037-05-000-02",
#                 "F00037-06-000-02",
#                 "F00037-07-000-02",
#                 "F00037-08-000-02"
#             ],
#             "ward_level": [
#                 "Benefit Level 1 with SMM (HKD)*",
#                 "Benefit Level 2 with SMM (HKD)*",
#                 "Benefit Level 3 with SMM (HKD)*",
#                 "Benefit Level 4 with SMM (HKD)*",
#                 "Benefit Level 1 with SMM (USD)*",
#                 "Benefit Level 2 with SMM (USD)*",
#                 "Benefit Level 3 with SMM (USD)*",
#                 "Benefit Level 4 with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00069-01-000-01",
#                 "F00069-02-000-01",
#                 "F00069-03-000-01",
#                 "F00069-04-000-01",
#                 "F00069-05-000-01",
#                 "F00069-06-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD16,000 Deductible*",
#                 "HKD25,000 Deductible*",
#                 "HKD50,000 Deductible*",
#                 "HKD100,000 Deductible*",
#                 "HKD180,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00051-01-000-02",
#                 "F00051-02-000-02"
#             ],
#             "ward_level": [
#                 "Standard*",
#                 "Superior*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00015-01-000-02"
#             ],
#             "ward_level": [
#                 "vCare Medical Plan*"
#             ],
#             "plan_premium": [
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00032-01-000-04"
#             ],
#             "ward_level": [
#                 "vCare Supreme Medical Plan*"
#             ],
# ...
#                 "F00019-02-001-03",
#                 "F00019-02-002-03",
#                 "F00019-03-000-03",
#                 "F00019-03-001-03",
#                 "F00019-03-002-03"
#             ],
#             "ward_level": [
#                 "Ward*",
#                 "Ward with SMM*",
#                 "Ward with SMM Plus*",
#                 "Semi-private Room*",
#                 "Semi-private Room with SMM*",
#                 "Semi-private Room with SMM Plus*",
#                 "Private Room*",
#                 "Private Room with SMM*",
#                 "Private Room with SMM Plus*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00071-01-000-01",
#                 "F00071-02-000-01",
#                 "F00071-03-000-01",
#                 "F00071-04-000-01",
#                 "F00071-05-000-01",
#                 "F00071-06-000-01",
#                 "F00071-07-000-01",
#                 "F00071-08-000-01",
#                 "F00071-09-000-01",
#                 "F00071-10-000-01",
#                 "F00071-11-000-01",
#                 "F00071-12-000-01",
#                 "F00071-13-000-01",
#                 "F00071-14-000-01",
#                 "F00071-15-000-01",
#                 "F00071-16-000-01"
#             ],
#             "ward_level": [
#                 "Advance (HKD0 Deductible)*",
#                 "Advance (HKD25,000 Deductible)*",
#                 "Advance (HKD50,000 Deductible)*",
#                 "Advance (HKD100,000 Deductible)*",
#                 "Advance (USD0 Deductible)*",
#                 "Advance (USD3,125 Deductible)*",
#                 "Advance (USD6,250 Deductible)*",
#                 "Advance (USD12,500 Deductible)*",
#                 "Smart (HKD0 Deductible)*",
#                 "Smart (HKD25,000 Deductible)*",
#                 "Smart (HKD50,000 Deductible)*",
#                 "Smart (HKD100,000 Deductible)*",
#                 "Smart (USD0 Deductible)*",
#                 "Smart (USD3,125 Deductible)*",
#                 "Smart (USD6,250 Deductible)*",
#                 "Smart (USD12,500 Deductible)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00041-01-000-04",
#                 "F00041-02-000-04",
#                 "F00041-03-000-04",
#                 "F00041-04-000-02",
#                 "F00041-05-000-01",
#                 "F00041-06-000-01",
#                 "F00041-07-000-01",
#                 "F00041-08-000-01",
#                 "F00041-09-000-01"
#             ],
#             "ward_level": [
#                 "Advance (HKD0 Deductible)*",
#                 "Advance (HKD8,000 Deductible)*",
#                 "Advance (HKD22,800 Deductible)*",
#                 "Advance (HKD45,000 Deductible)*",
#                 "Advance (HKD100,000 Deductible)*",
#                 "Smart (HKD0 Deductible)*",
#                 "Smart (HKD22,800 Deductible)*",
#                 "Smart (HKD45,000 Deductible)*",
#                 "Smart (HKD100,000 Deductible)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00023-01-000-02",
#                 "F00023-01-001-02",
#                 "F00023-02-000-02",
#                 "F00023-02-001-02",
#                 "F00023-03-000-02",
#                 "F00023-03-001-02"
#             ],
#             "ward_level": [
#                 "Plan A*",
#                 "Plan A with SMM*",
#                 "Plan B*",
#                 "Plan B with SMM*",
#                 "Plan C*",
#                 "Plan C with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00013-01-000-05",
#                 "F00013-01-001-05",
#                 "F00013-01-002-05",
#                 "F00013-02-000-05",
#                 "F00013-02-001-05",
#                 "F00013-02-002-05",
#                 "F00013-03-000-05",
#                 "F00013-03-001-05",
#                 "F00013-04-000-05",
#                 "F00013-04-001-05",
#                 "F00013-04-002-05",
#                 "F00013-05-000-05",
#                 "F00013-05-001-05",
#                 "F00013-05-002-05",
#                 "F00013-06-000-05",
#                 "F00013-06-001-05"
#             ],
#             "ward_level": [
#                 "Ward (HKD)*",
#                 "Ward with SMM 1 (HKD)*",
#                 "Ward with SMM 2 (HKD)*",
#                 "Semi-private Room (HKD)*",
#                 "Semi-private Room with SMM 1 (HKD)*",
#                 "Semi-private Room with SMM 2 (HKD)*",
#                 "Private Room (HKD)*",
#                 "Private Room with SMM (HKD)*",
#                 "Ward (USD)*",
#                 "Ward with SMM 1 (USD)*",
#                 "Ward with SMM 2 (USD)*",
#                 "Semi-private Room (USD)*",
#                 "Semi-private Room with SMM 1 (USD)*",
#                 "Semi-private Room with SMM 2 (USD)*",
#                 "Private Room (USD)*",
#                 "Private Room with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00068-01-000-01",
#                 "F00068-02-000-01",
#                 "F00068-03-000-01",
#                 "F00068-04-000-01",
#                 "F00068-05-000-01",
#                 "F00068-06-000-01"
#             ],
#             "ward_level": [
#                 "Ward with SMM (HKD)*",
#                 "Semi-private Room with SMM (HKD)*",
#                 "Private Room with SMM (HKD)*",
#                 "Ward with SMM (USD)*",
#                 "Semi-private Room with SMM (USD)*",
#                 "Private Room with SMM (USD)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00050-01-000-04",
#                 "F00050-02-000-04",
#                 "F00050-03-000-04",
#                 "F00050-04-000-04",
#                 "F00050-05-000-04",
#                 "F00050-06-000-04",
#                 "F00050-07-000-01",
#                 "F00050-08-000-01",
#                 "F00050-09-000-01",
#                 "F00050-10-000-01",
#                 "F00050-11-000-01",
#                 "F00050-12-000-01",
#                 "F00050-13-000-01",
#                 "F00050-14-000-01",
#                 "F00050-15-000-01",
#                 "F00050-16-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia)*",
#                 "HKD20,000 Deductible (Asia)*",
#                 "HKD50,000 Deductible (Asia)*",
#                 "USD0 Deductible (Asia)*",
#                 "USD2,500 Deductible (Asia)*",
#                 "USD6,250 Deductible (Asia)*",
#                 "HKD96,000 Deductible (Asia)*",
#                 "USD12,000 Deductible (Asia)*",
#                 "HKD0 Deductible (Worldwide except USA)*",
#                 "HKD20,000 Deductible (Worldwide except USA)*",
#                 "HKD50,000 Deductible (Worldwide except USA)*",
#                 "HKD96,000 Deductible (Worldwide except USA)*",
#                 "USD0 Deductible (Worldwide except USA)*",
#                 "USD2,500 Deductible (Worldwide except USA)*",
#                 "USD6,250 Deductible (Worldwide except USA)*",
#                 "USD12,000 Deductible (Worldwide except USA)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00026-01-000-02",
#                 "F00026-01-001-02"
#             ],
#             "ward_level": [
#                 "Scheme 1*",
#                 "Scheme 2*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00066-01-000-01",
#                 "F00066-02-000-01",
#                 "F00066-03-000-01",
#                 "F00066-04-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD20,000 Deductible*",
#                 "HKD50,000 Deductible*",
#                 "HKD80,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00063-01-000-01",
#                 "F00063-02-000-01",
#                 "F00063-03-000-01",
#                 "F00063-04-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD20,000 Deductible*",
#                 "HKD50,000 Deductible*",
#                 "HKD80,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00042-01-000-02",
#                 "F00042-02-000-02",
#                 "F00042-03-000-02"
#             ],
#             "ward_level": [
#                 "Ward*",
#                 "Semi-Private*",
#                 "Standard Private*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00020-01-000-03",
#                 "F00020-01-001-03",
#                 "F00020-02-000-03",
#                 "F00020-02-001-03",
#                 "F00020-03-000-03",
#                 "F00020-03-001-03",
#                 "F00020-04-000-03",
#                 "F00020-04-001-03",
#                 "F00020-05-000-01",
#                 "F00020-05-001-01"
#             ],
#             "ward_level": [
#                 "Plan 1*",
#                 "Plan 1M*",
#                 "Plan 2*",
#                 "Plan 2M*",
#                 "Plan 3*",
#                 "Plan 3M*",
#                 "Plan 4*",
#                 "Plan 4M*",
#                 "Plan X*",
#                 "Plan XM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00065-01-000-01",
#                 "F00065-02-000-01",
#                 "F00065-03-000-01",
#                 "F00065-04-000-01"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible*",
#                 "HKD15,000 Deductible*",
#                 "HKD30,000 Deductible*",
#                 "HKD100,000 Deductible*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00036-01-000-02",
#                 "F00036-02-000-02",
#                 "F00036-03-000-02",
#                 "F00036-04-000-02",
#                 "F00036-05-000-02",
#                 "F00036-06-000-02",
#                 "F00036-07-000-02",
#                 "F00036-08-000-02"
#             ],
#             "ward_level": [
#                 "HKD0 Deductible (Asia)*",
#                 "HKD60,000 Deductible (Asia)*",
#                 "HKD90,000 Deductible (Asia)*",
#                 "HKD150,000 Deductible (Asia)*",
#                 "HKD0 Deductible (Worldwide excluding the U.S.)*",
#                 "HKD60,000 Deductible (Worldwide excluding the U.S.)*",
#                 "HKD90,000 Deductible (Worldwide excluding the U.S.)*",
#                 "HKD150,000 Deductible (Worldwide excluding the U.S.)*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         },
#         {
#             "cert_no": [
#                 "F00044-01-000-02",
#                 "F00044-01-001-02",
#                 "F00044-02-000-02",
#                 "F00044-02-001-02"
#             ],
#             "ward_level": [
#                 "Essential*",
#                 "Essential with SMM*",
#                 "Advanced*",
#                 "Advanced with SMM*"
#             ],
#             "plan_premium": [
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium",
#                 "Standard Premium"
#             ]
#         }
#     ]
# }
# {
#     "cert_no": [
#         "F00044-01-000-02",
#         "F00044-01-001-02",
#         "F00044-02-000-02",
#         "F00044-02-001-02"
#     ],
#     "ward_level": [
#         "Essential*",
#         "Essential with SMM*",
#         "Advanced*",
#         "Advanced with SMM*"
#     ],
#     "plan_premium": [
#         "Standard Premium",
#         "Standard Premium",
#         "Standard Premium",
#         "Standard Premium"
#     ]
# }

# %%
data
# Out:
# {'plan': {'plan_name': ['AIA Voluntary Health Insurance Flexi Scheme',
#    'AIA Voluntary Health Insurance Prime Scheme',
#    'AIA Voluntary Health Insurance Privilege Scheme',
#    'AIA Voluntary Health Insurance Privilege Plus Scheme',
#    'AIA Voluntary Health Insurance Privilege Ultra Scheme',
#    'Allianz Ultra Medical Protect##The insurance company offering this Certified Plan has ceased to maintain its registration as a VHIS Provider from 1 July 2022. Upon the effective date of de-registration, only renewals are available for existing policies of this Certified Plan. Also, there will not be further updates of relevant product and premium on this webpage thereafter. Please contact the insurance company for the latest updates of the Certified Plan.*Supplement on value-added tax & goods and services tax',
#    'Asia Elite',
#    'Asia iCare',
#    'AXA WiseGuard Pro Medical Insurance Plan',
#    'Smart Medicare',
#    'Smart Medicare',
#    'BOC Flexi Voluntary Health Insurance Scheme Certified Plan',
#    'Blue Cross Dynasty VHIS Plan',
#    'Blue Cross Love Yourself VHIS Plan',
#    'CareForYou Flexi Plan for VHIS',
#    'CareForYou Super Flexi Plan for VHIS',
#    'SmartViva Flexi VHIS',
#    'Bowtie Pink VHIS Plan',
#    'Bowtie VHIS Flexi',
#    'Bupa Hero VHIS Plan',
#    'Bupa MyFlexi VHIS Plan',
#    'Global Prestige VHIS Plan',
#    'Healthy Life Medical Insurance Plan',
#    'Healthy Life Premier Medical Insurance Plan',
#    'Taiping Life VHIS Flexi Plan',
#    'Taiping Life VHIS Priority Plan',
#    'Chubb VHIS - Flexi Plan',
#    'Chubb VHIS - Prime Plan',
#    "VHIS Series - Flexi Plan (SMM)(Formerly known as ''Cigna VHIS Series - Flexi Plan (SMM)'')",
#    "VHIS Series - Flexi Plan (Superior)(Formerly known as ''Cigna VHIS Series - Flexi Plan (Superior)'')",
#    'Cigna VHIS Series - Flexi Plan (SMM)',
#    'Cigna VHIS Series - Flexi Plan (Superior)',
#    "''BetterCare'' Medical Insurance Plan",
#    "''FlexiCare'' Medical Insurance Plan",
#    "''TopCare'' Medical Insurance Plan",
#    'vBooster Medical Plan',
#    'vCANsurance Medical Plan',
#    'vCare Medical Plan',
#    'vCare Supreme Medical Plan',
#    'vFamily Medical Plan',
#    'vPrime Medical Plan',
#    'vPrime Signature Medical Plan',
#    'vTheOne Medical Plan',
#    'Health Supreme Medical Plan',
#    'HSBC Voluntary Health Insurance Flexi Plan',
#    'Liberty Insurance VHIS Series - Flexi Plan (Classic)',
#    'Liberty Insurance VHIS Series - Flexi Plan (Plus)',
#    'Liberty Insurance VHIS Series - Flexi Plan (Premium)',
#    'Manulife First VHIS Flexi Plan',
#    'Manulife Supreme Lite VHIS Supplementary Benefit',
#    'Manulife Supreme VHIS Flexi Plan',
#    'VHIS Prestige Care',
#    'PRUHealth FlexiChoice Medical Plan',
#    'PRUHealth VHIS EasyChoice Plan',
#    'PRUHealth VHIS VIP Plan',
#    'WeHealth Plus',
#    'WeHealth Preferred',
#    'WeHealth Prestige',
#    'Well Protect Voluntary Health Insurance Scheme (Flexi)',
#    'TaxVantage Plus Medical Plan',
#    'TaxVantage Prestige Medical Plan',
#    'HealthFlexi Plus Voluntary Health Insurance Plan',
#    'HealthFlexi Voluntary Health Insurance Plan'],
#   'insurer': ['AIA International Limited',
#    'AIA International Limited',
#    'AIA International Limited',
#    'AIA International Limited',
#    'AIA International Limited',
#    'Allianz Global Corporate & Specialty SE',
#    'Asia Insurance Company, Limited',
#    'Asia Insurance Company, Limited',
#    'AXA China Region Insurance Company (Bermuda) Limited',
#    'AXA China Region Insurance Company (Bermuda) Limited',
#    'AXA China Region Insurance Company Limited',
#    'Bank of China Group Insurance Company Limited',
#    'Blue Cross (Asia-Pacific) Insurance Limited',
#    'Blue Cross (Asia-Pacific) Insurance Limited',
#    'Blue Cross (Asia-Pacific) Insurance Limited',
#    'Blue Cross (Asia-Pacific) Insurance Limited',
#    'BOC Group Life Assurance Company Limited',
#    'Bowtie Life Insurance Company Limited',
#    'Bowtie Life Insurance Company Limited',
#    'Bupa (Asia) Limited',
#    'Bupa (Asia) Limited',
#    'Bupa (Asia) Limited',
#    'China Life Insurance (Overseas) Company Limited',
#    'China Life Insurance (Overseas) Company Limited',
#    'China Taiping Life Insurance (Hong Kong) Company Limited',
#    'China Taiping Life Insurance (Hong Kong) Company Limited',
#    "Chubb Life Insurance Hong Kong Limited\n(Formerly underwritten by ''Chubb Life Insurance Company Ltd.'')",
#    'Chubb Life Insurance Hong Kong Limited',
#    "Chubb Life Insurance Hong Kong Limited\n(Formerly known as ''Cigna Worldwide Life Insurance Company Limited'')",
#    "Chubb Life Insurance Hong Kong Limited\n(Formerly known as ''Cigna Worldwide Life Insurance Company Limited'')",
#    'CIGNA Worldwide General Insurance Company Limited',
#    'CIGNA Worldwide General Insurance Company Limited',
#    'FTLife Insurance Company Limited',
#    'FTLife Insurance Company Limited',
#    'FTLife Insurance Company Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'FWD Life Insurance Company (Bermuda) Limited',
#    'Hong Kong Life Insurance Limited',
#    'HSBC Life (International) Limited',
#    'Liberty International Insurance Limited',
#    'Liberty International Insurance Limited',
#    'Liberty International Insurance Limited',
#    'Manulife (International) Limited',
#    'Manulife (International) Limited',
#    'Manulife (International) Limited',
#    'MSIG Insurance (Hong Kong) Limited',
#    'Prudential Hong Kong Limited',
#    'Prudential Hong Kong Limited',
#    'Prudential Hong Kong Limited',
#    'Sun Life Hong Kong Limited',
#    'Sun Life Hong Kong Limited',
#    'Sun Life Hong Kong Limited',
#    'Well Link Life Insurance Company Limited',
#    'YF Life Insurance International Limited',
#    'YF Life Insurance International Limited',
#    'Zurich Insurance Company Ltd',
#    'Zurich Insurance Company Ltd'],
#   'effective_date': ['15 July 2023',
#    '22 April 2024',
#    '22 April 2024',
#    '22 April 2024',
#    '22 April 2024',
#    '1 April 2021',
#    '1 April 2021',
#    '22 November 2021',
#    '31 July 2023',
#    '31 July 2023',
#    '31 July 2023',
#    '1 April 2021',
#    '1 January 2024',
#    '15 March 2024',
#    '1 January 2024',
#    '1 January 2024',
#    '1 August 2022',
#    '7 December 2023',
#    '7 December 2023',
#    '2 March 2024',
#    '2 March 2024',
#    '2 December 2023',
#    '1 April 2021',
#    '1 April 2021',
#    '7 July 2021',
#    '1 January 2023',
#    '1 April 2024',
#    '16 April 2024',
#    '1 November 2022',
#    '1 November 2022',
#    '1 July 2023',
#    '1 July 2023',
#    '23 November 2023',
#    '16 May 2022',
#    '23 November 2023',
#    '9 January 2023',
#    '15 April 2024',
#    '1 August 2023',
#    '15 April 2024',
#    '4 March 2024',
#    '15 November 2023',
#    '9 October 2023',
#    '11 July 2022',
#    '12 October 2020',
#    '29 March 2021',
#    '1 July 2021',
#    '1 July 2021',
#    '1 July 2021',
#    '1 October 2022',
#    '6 November 2023',
#    '29 December 2023',
#    '1 April 2021',
#    '1 July 2023',
#    '3 October 2022',
#    '1 April 2023',
#    '1 April 2022',
#    '18 March 2022',
#    '21 January 2022',
#    '30 October 2020',
#    '1 January 2024',
#    '1 January 2024',
#    '19 March 2021',
#    '19 March 2021'],
#   'earliest_date': ['1 April 2019',
#    '15 April 2019',
#    '22 February 2021',
#    '15 March 2021',
#    '',
#    '29 July 2019',
#    '2 October 2019',
#    '',
#    '25 July 2019',
#    '1 April 2019',
#    '1 April 2019',
#    '28 June 2019',
#    '16 August 2021',
#    '',
#    '1 April 2019',
#    '28 February 2020',
#    '26 July 2021',
#    '28 October 2021',
#    '8 July 2019',
#    '3 February 2020',
#    '24 May 2019',
#    '19 August 2019',
#    '1 April 2019',
#    '3 June 2019',
#    '20 January 2021',
#    '22 November 2021',
#    '14 May 2019',
#    '',
#    '24 March 2021',
#    '24 March 2021',
#    '1 April 2019',
#    '1 April 2019',
#    '1 April 2019',
#    '',
#    '30 August 2019',
#    '',
#    '12 October 2020',
#    '1 April 2019',
#    '22 July 2019',
#    '',
#    '1 May 2020',
#    '',
#    '',
#    '6 December 2019',
#    '20 July 2020',
#    '15 June 2020',
#    '15 June 2020',
#    '15 June 2020',
#    '1 April 2019',
#    '',
#    '17 February 2020',
#    '1 April 2019',
#    '1 April 2019',
#    '',
#    '3 September 2020',
#    '2 May 2019',
#    '',
#    '',
#    '6 February 2020',
#    '1 April 2019',
#    '18 February 2022',
#    '16 October 2019',
#    '6 August 2020']},
#  'certifications': [{'cert_no': ['F00022-01-000-03',
#     'F00022-02-000-03',
#     'F00022-03-000-03',
#     'F00022-04-000-03',
#     'F00022-05-000-03',
#     'F00022-06-000-03'],
#    'ward_level': ['Ward (HKD)*',
#     'Semi-private (HKD)*',
#     'Standard Private (HKD)*',
#     'Ward (USD)*',
#     'Semi-private (USD)*',
#     'Standard Private (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00025-01-000-03',
#     'F00025-02-000-03',
#     'F00025-03-000-03',
#     'F00025-04-000-03',
#     'F00025-05-000-03',
#     'F00025-06-000-03'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD16,000 Deductible*',
#     'HKD25,000 Deductible*',
#     'USD0 Deductible*',
#     'USD2,000 Deductible*',
#     'USD3,125 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00053-01-000-02',
#     'F00053-02-000-02',
#     'F00053-03-000-02',
#     'F00053-04-000-02',
#     'F00053-05-000-02',
#     'F00053-06-000-02'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD16,000 Deductible*',
#     'HKD25,000 Deductible*',
#     'USD0 Deductible*',
#     'USD2,000 Deductible*',
#     'USD3,125 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00054-01-000-02',
#     'F00054-02-000-02',
#     'F00054-03-000-02',
#     'F00054-04-000-02',
#     'F00054-05-000-02',
#     'F00054-06-000-02'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD16,000 Deductible*',
#     'HKD25,000 Deductible*',
#     'USD0 Deductible*',
#     'USD2,000 Deductible*',
#     'USD3,125 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00074-01-000-01',
#     'F00074-02-000-01',
#     'F00074-03-000-01',
#     'F00074-04-000-01',
#     'F00074-05-000-01',
#     'F00074-06-000-01',
#     'F00074-07-000-01',
#     'F00074-08-000-01',
#     'F00074-09-000-01',
#     'F00074-10-000-01',
#     'F00074-11-000-01',
#     'F00074-12-000-01',
#     'F00074-13-000-01',
#     'F00074-14-000-01',
#     'F00074-15-000-01',
#     'F00074-16-000-01'],
#    'ward_level': ['HKD0 Deductible (Asia)*',
#     'HKD16,000 Deductible (Asia)*',
#     'HKD25,000 Deductible (Asia)*',
#     'HKD50,000 Deductible (Asia)*',
#     'HKD0 Deductible (Worldwide except USA)*',
#     'HKD16,000 Deductible (Worldwide except USA)*',
#     'HKD25,000 Deductible (Worldwide except USA)*',
#     'HKD50,000 Deductible (Worldwide except USA)*',
#     'USD0 Deductible (Asia)*',
#     'USD2,000 Deductible (Asia)*',
#     'USD3,125 Deductible (Asia)*',
#     'USD6,250 Deductible (Asia)*',
#     'USD0 Deductible (Worldwide except USA)*',
#     'USD2,000 Deductible (Worldwide except USA)*',
#     'USD3,125 Deductible (Worldwide except USA)*',
#     'USD6,250 Deductible (Worldwide except USA)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00033-01-000-02',
#     'F00033-01-001-02',
#     'F00033-02-000-02',
#     'F00033-02-001-02'],
#    'ward_level': ['Silver Plan*',
#     'Silver Plan with SMM*',
#     'Gold Plan*',
#     'Gold Plan with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00038-01-000-02', 'F00038-02-000-02'],
#    'ward_level': ['Semi-Private Room*', 'Standard Private Room*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00061-01-000-01',
#     'F00061-01-001-01',
#     'F00061-02-000-01',
#     'F00061-02-001-01',
#     'F00061-02-002-01'],
#    'ward_level': ['Plan 1*',
#     'Plan 1A with SMM*',
#     'Plan 2*',
#     'Plan 2A with SMM*',
#     'Plan 2B with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00034-01-000-04',
#     'F00034-02-000-04',
#     'F00034-03-000-04',
#     'F00034-04-000-04',
#     'F00034-05-000-04',
#     'F00034-06-000-04',
#     'F00034-07-000-04',
#     'F00034-08-000-04',
#     'F00034-09-000-04',
#     'F00034-10-000-04',
#     'F00034-11-000-04',
#     'F00034-12-000-04',
#     'F00034-13-000-04',
#     'F00034-14-000-04',
#     'F00034-15-000-04',
#     'F00034-16-000-04',
#     'F00034-17-000-04',
#     'F00034-18-000-04',
#     'F00034-19-000-02',
#     'F00034-20-000-02',
#     'F00034-21-000-02',
#     'F00034-22-000-02',
#     'F00034-23-000-02',
#     'F00034-24-000-02'],
#    'ward_level': ['Regular (HKD0 Deductible)*',
#     'Regular (HKD20,000 Deductible)*',
#     'Regular (HKD50,000 Deductible)*',
#     'Enhance (HKD0 Deductible)*',
#     'Enhance (HKD20,000 Deductible)*',
#     'Enhance (HKD50,000 Deductible)*',
#     'Premier (HKD0 Deductible)*',
#     'Premier (HKD20,000 Deductible)*',
#     'Premier (HKD50,000 Deductible)*',
#     'Regular (USD0 Deductible)*',
#     'Regular (USD2,500 Deductible)*',
#     'Regular (USD6,250 Deductible)*',
#     'Enhance (USD0 Deductible)*',
#     'Enhance (USD2,500 Deductible)*',
#     'Enhance (USD6,250 Deductible)*',
#     'Premier (USD0 Deductible)*',
#     'Premier (USD2,500 Deductible)*',
#     'Premier (USD6,250 Deductible)*',
#     'Noble (HKD0 Deductible)*',
#     'Noble (HKD20,000 Deductible)*',
#     'Noble (HKD50,000 Deductible)*',
#     'Noble (USD0 Deductible)*',
#     'Noble (USD2,500 Deductible)*',
#     'Noble (USD6,250 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00017-01-000-03',
#     'F00017-01-001-03',
#     'F00017-02-000-03',
#     'F00017-02-001-03',
#     'F00017-03-000-03',
#     'F00017-03-001-03',
#     'F00017-04-000-03',
#     'F00017-04-001-03',
#     'F00017-05-000-03',
#     'F00017-05-001-03',
#     'F00017-06-000-03',
#     'F00017-06-001-03'],
#    'ward_level': ['Regular (HKD)*',
#     'Regular with SMM (HKD)*',
#     'Superior (HKD)*',
#     'Superior with SMM (HKD)*',
#     'Premier (HKD)*',
#     'Premier with SMM (HKD)*',
#     'Regular (USD)*',
#     'Regular with SMM (USD)*',
#     'Superior (USD)*',
#     'Superior with SMM (USD)*',
#     'Premier (USD)*',
#     'Premier with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00018-01-000-03',
#     'F00018-01-001-03',
#     'F00018-02-000-03',
#     'F00018-02-001-03',
#     'F00018-03-000-03',
#     'F00018-03-001-03',
#     'F00018-04-000-03',
#     'F00018-04-001-03',
#     'F00018-05-000-03',
#     'F00018-05-001-03',
#     'F00018-06-000-03',
#     'F00018-06-001-03'],
#    'ward_level': ['Regular (HKD)*',
#     'Regular with SMM (HKD)*',
#     'Superior (HKD)*',
#     'Superior with SMM (HKD)*',
#     'Premier (HKD)*',
#     'Premier with SMM (HKD)*',
#     'Regular (USD)*',
#     'Regular with SMM (USD)*',
#     'Superior (USD)*',
#     'Superior with SMM (USD)*',
#     'Premier (USD)*',
#     'Premier with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00028-01-000-02',
#     'F00028-01-001-02',
#     'F00028-01-002-02',
#     'F00028-01-003-02',
#     'F00028-01-004-02',
#     'F00028-01-005-02',
#     'F00028-01-006-02',
#     'F00028-01-007-02'],
#    'ward_level': ['Basic plan*',
#     'Basic plan with upgraded benefits 1*',
#     'Basic plan with upgraded benefits 2*',
#     'Basic plan with upgraded benefits 3*',
#     'Basic plan with SMM*',
#     'Basic plan with SMM & upgraded benefits 1*',
#     'Basic plan with SMM & upgraded benefits 2*',
#     'Basic plan with SMM & upgraded benefits 3*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00059-01-000-01',
#     'F00059-02-000-01',
#     'F00059-03-000-01',
#     'F00059-04-000-01',
#     'F00059-05-000-01',
#     'F00059-06-000-01',
#     'F00059-07-000-01',
#     'F00059-08-000-01'],
#    'ward_level': ['HKD0 Deductible (Asia & Australia-New Zealand)*',
#     'HKD20,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD40,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD80,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD0 Deductible (Worldwide )*',
#     'HKD20,000 Deductible (Worldwide )*',
#     'HKD40,000 Deductible (Worldwide )*',
#     'HKD80,000 Deductible (Worldwide )*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00073-01-000-01',
#     'F00073-02-000-01',
#     'F00073-03-000-01',
#     'F00073-04-000-01',
#     'F00073-05-000-01',
#     'F00073-06-000-01',
#     'F00073-07-000-01',
#     'F00073-08-000-01'],
#    'ward_level': ['HKD0 Deductible (Asia & Australia-New Zealand)*',
#     'HKD20,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD40,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD80,000 Deductible (Asia & Australia-New Zealand)*',
#     'HKD0 Deductible (Worldwide )*',
#     'HKD20,000 Deductible (Worldwide )*',
#     'HKD40,000 Deductible (Worldwide )*',
#     'HKD80,000 Deductible (Worldwide )*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00014-01-000-02'],
#    'ward_level': ['CareForYou*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00043-01-000-02',
#     'F00043-01-001-02',
#     'F00043-01-002-02',
#     'F00043-02-000-02',
#     'F00043-02-001-02',
#     'F00043-02-002-02',
#     'F00043-03-000-02',
#     'F00043-03-001-02',
#     'F00043-03-002-02',
#     'F00043-04-000-02'],
#    'ward_level': ['Plan A*',
#     'Plan A with SMM (No Coinsurance)*',
#     'Plan A with SMM (with 20% Coinsurance)*',
#     'Plan B*',
#     'Plan B with SMM (No Coinsurance)*',
#     'Plan B with SMM (with 20% Coinsurance)*',
#     'Plan C*',
#     'Plan C with SMM (No Coinsurance)*',
#     'Plan C with SMM (with 20% Coinsurance)*',
#     'Plan D with SMM (with 20% Coinsurance)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00057-01-000-02',
#     'F00057-02-000-02',
#     'F00057-03-000-02',
#     'F00057-04-000-02'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD10,000 Deductible*',
#     'HKD30,000 Deductible*',
#     'HKD70,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00060-01-000-04',
#     'F00060-02-000-04',
#     'F00060-03-000-04',
#     'F00060-04-000-04',
#     'F00060-05-000-04',
#     'F00060-06-000-04',
#     'F00060-07-000-04',
#     'F00060-08-000-04',
#     'F00060-09-000-01',
#     'F00060-10-000-01',
#     'F00060-11-000-01',
#     'F00060-12-000-01'],
#    'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#     'Semi-Private Room - HKD20,000 Deductible*',
#     'Semi-Private Room - HKD50,000 Deductible*',
#     'Semi-Private Room - HKD80,000 Deductible*',
#     'Private Room - HKD0 Deductible*',
#     'Private Room - HKD20,000 Deductible*',
#     'Private Room - HKD50,000 Deductible*',
#     'Private Room - HKD80,000 Deductible*',
#     'Ward Room - HKD0 Deductible*',
#     'Ward Room - HKD20,000 Deductible*',
#     'Ward Room - HKD50,000 Deductible*',
#     'Ward Room - HKD80,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00031-01-000-05', 'F00031-02-000-05'],
#    'ward_level': ['Regular*', 'Plus*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00040-01-000-03',
#     'F00040-02-000-03',
#     'F00040-03-000-03',
#     'F00040-04-000-03',
#     'F00040-05-000-03',
#     'F00040-06-000-03',
#     'F00040-07-000-03',
#     'F00040-08-000-03',
#     'F00040-09-000-01',
#     'F00040-10-000-01',
#     'F00040-11-000-01',
#     'F00040-12-000-01',
#     'F00040-13-000-01',
#     'F00040-14-000-01',
#     'F00040-15-000-01',
#     'F00040-16-000-01'],
#    'ward_level': ['Advance (HKD0 Deductible)*',
#     'Advance (HKD12,000 Deductible)*',
#     'Advance (HKD40,000 Deductible)*',
#     'Advance (HKD80,000 Deductible)*',
#     'Deluxe (HKD0 Deductible)*',
#     'Deluxe (HKD12,000 Deductible)*',
#     'Deluxe (HKD40,000 Deductible)*',
#     'Deluxe (HKD80,000 Deductible)*',
#     'Advance Pro (HKD0 Deductible)*',
#     'Advance Pro (HKD12,000 Deductible)*',
#     'Advance Pro (HKD40,000 Deductible)*',
#     'Advance Pro (HKD80,000 Deductible)*',
#     'Deluxe Pro (HKD0 Deductible)*',
#     'Deluxe Pro (HKD12,000 Deductible)*',
#     'Deluxe Pro (HKD40,000 Deductible)*',
#     'Deluxe Pro (HKD80,000 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00029-01-000-05',
#     'F00029-01-001-05',
#     'F00029-02-000-05',
#     'F00029-02-001-05',
#     'F00029-03-000-05',
#     'F00029-03-001-05'],
#    'ward_level': ['Standard*',
#     'Standard Plus*',
#     'Advance*',
#     'Advance Plus*',
#     'Deluxe*',
#     'Deluxe Plus*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00035-01-000-04',
#     'F00035-02-000-04',
#     'F00035-03-000-04',
#     'F00035-04-000-04'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD12,000 Deductible*',
#     'HKD40,000 Deductible*',
#     'HKD80,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00024-01-000-02'],
#    'ward_level': ['Healthy Life Medical Insurance Plan*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00030-01-000-02',
#     'F00030-01-001-02',
#     'F00030-02-000-02',
#     'F00030-02-001-02'],
#    'ward_level': ['Semi-private*',
#     'Semi-private with SMM*',
#     'Private*',
#     'Private with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00052-01-000-01',
#     'F00052-02-000-01',
#     'F00052-02-001-01',
#     'F00052-03-000-01',
#     'F00052-03-001-01'],
#    'ward_level': ['Plan 1 - Ward with SMM*',
#     'Plan 2 - Semi-Private Room*',
#     'Plan 3 - Semi-Private Room with SMM*',
#     'Plan 4 - Standard Private Room*',
#     'Plan 5 - Standard Private Room with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00062-01-000-02',
#     'F00062-02-000-02',
#     'F00062-03-000-02',
#     'F00062-04-000-02',
#     'F00062-05-000-02',
#     'F00062-06-000-02'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD20,000 Deductible*',
#     'HKD50,000 Deductible*',
#     'USD0 Deductible*',
#     'USD2,500 Deductible*',
#     'USD6,250 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00027-01-000-03',
#     'F00027-01-001-03',
#     'F00027-02-000-03',
#     'F00027-02-001-03',
#     'F00027-03-000-03',
#     'F00027-03-001-03',
#     'F00027-04-000-03',
#     'F00027-04-001-03',
#     'F00027-05-000-03',
#     'F00027-05-001-03',
#     'F00027-06-000-03',
#     'F00027-06-001-03',
#     'F00027-07-000-03',
#     'F00027-07-001-03',
#     'F00027-08-000-03',
#     'F00027-08-001-03'],
#    'ward_level': ['Classic (HKD)*',
#     'Classic with Top-up benefit (HKD)*',
#     'Ward (HKD)*',
#     'Ward with Top-up benefit (HKD)*',
#     'Semi-Private (HKD)*',
#     'Semi-Private with Top-up benefit (HKD)*',
#     'Private (HKD)*',
#     'Private with Top-up benefit (HKD)*',
#     'Classic (USD)*',
#     'Classic with Top-up benefit (USD)*',
#     'Ward (USD)*',
#     'Ward with Top-up benefit (USD)*',
#     'Semi-Private (USD)*',
#     'Semi-Private with Top-up benefit (USD)*',
#     'Private (USD)*',
#     'Private with Top-up benefit (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00075-01-000-01',
#     'F00075-02-000-01',
#     'F00075-03-000-01',
#     'F00075-04-000-01',
#     'F00075-05-000-01',
#     'F00075-06-000-01',
#     'F00075-07-000-01',
#     'F00075-08-000-01',
#     'F00075-09-000-01',
#     'F00075-10-000-01'],
#    'ward_level': ['HKD0 Deductible (Asia)*',
#     'HKD25,000 Deductible (Asia)*',
#     'HKD50,000 Deductible (Asia)*',
#     'HKD100,000 Deductible (Asia)*',
#     'HKD150,000 Deductible (Asia)*',
#     'HKD0 Deductible (Worldwide excluding USA)*',
#     'HKD25,000 Deductible (Worldwide excluding USA)*',
#     'HKD50,000 Deductible (Worldwide excluding USA)*',
#     'HKD100,000 Deductible (Worldwide excluding USA)*',
#     'HKD150,000 Deductible (Worldwide excluding USA)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00055-01-000-02'],
#    'ward_level': ['Flexi Plan SMM*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00056-01-000-03',
#     'F00056-02-000-03',
#     'F00056-03-000-03',
#     'F00056-04-000-03',
#     'F00056-05-000-03',
#     'F00056-06-000-02',
#     'F00056-07-000-02',
#     'F00056-08-000-02'],
#    'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#     'Semi-Private Room - HKD15,000 Deductible*',
#     'Semi-Private Room - HKD25,000 Deductible*',
#     'Semi-Private Room - HKD50,000 Deductible*',
#     'Semi-Private Room - HKD75,000 Deductible*',
#     'Standard Ward - HKD0 Deductible*',
#     'Standard Ward - HKD15,000 Deductible*',
#     'Standard Ward - HKD25,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00012-01-000-03'],
#    'ward_level': ['Flexi Plan SMM*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00016-01-000-04',
#     'F00016-02-000-04',
#     'F00016-03-000-04',
#     'F00016-04-000-04',
#     'F00016-05-000-03',
#     'F00016-06-000-02',
#     'F00016-07-000-02',
#     'F00016-08-000-02'],
#    'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#     'Semi-Private Room - HKD15,000 Deductible*',
#     'Semi-Private Room - HKD25,000 Deductible*',
#     'Semi-Private Room - HKD50,000 Deductible*',
#     'Semi-Private Room - HKD75,000 Deductible*',
#     'Standard Ward - HKD0 Deductible*',
#     'Standard Ward - HKD15,000 Deductible*',
#     'Standard Ward - HKD25,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00021-01-000-02',
#     'F00021-02-000-02',
#     'F00021-03-000-02',
#     'F00021-04-000-02',
#     'F00021-05-000-02',
#     'F00021-06-000-02'],
#    'ward_level': ['Benefit Level 1 with SMM (HKD)*',
#     'Benefit Level 2 with SMM (HKD)*',
#     'Benefit Level 3 with SMM (HKD)*',
#     'Benefit Level 1 with SMM (USD)*',
#     'Benefit Level 2 with SMM (USD)*',
#     'Benefit Level 3 with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00064-01-000-01',
#     'F00064-02-000-01',
#     'F00064-03-000-01',
#     'F00064-04-000-01'],
#    'ward_level': ['Benefit Level 1 (HKD)*',
#     'Benefit Level 2 (HKD)*',
#     'Benefit Level 1 (USD)*',
#     'Benefit Level 2 (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00037-01-000-02',
#     'F00037-02-000-02',
#     'F00037-03-000-02',
#     'F00037-04-000-02',
#     'F00037-05-000-02',
#     'F00037-06-000-02',
#     'F00037-07-000-02',
#     'F00037-08-000-02'],
#    'ward_level': ['Benefit Level 1 with SMM (HKD)*',
#     'Benefit Level 2 with SMM (HKD)*',
#     'Benefit Level 3 with SMM (HKD)*',
#     'Benefit Level 4 with SMM (HKD)*',
#     'Benefit Level 1 with SMM (USD)*',
#     'Benefit Level 2 with SMM (USD)*',
#     'Benefit Level 3 with SMM (USD)*',
#     'Benefit Level 4 with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00069-01-000-01',
#     'F00069-02-000-01',
#     'F00069-03-000-01',
#     'F00069-04-000-01',
#     'F00069-05-000-01',
#     'F00069-06-000-01'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD16,000 Deductible*',
#     'HKD25,000 Deductible*',
#     'HKD50,000 Deductible*',
#     'HKD100,000 Deductible*',
#     'HKD180,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00051-01-000-02', 'F00051-02-000-02'],
#    'ward_level': ['Standard*', 'Superior*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00015-01-000-02'],
#    'ward_level': ['vCare Medical Plan*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00032-01-000-04'],
#    'ward_level': ['vCare Supreme Medical Plan*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00072-01-000-01'],
#    'ward_level': ['Standard*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00045-01-000-04',
#     'F00045-02-000-04',
#     'F00045-03-000-04',
#     'F00045-04-000-04',
#     'F00045-05-000-02',
#     'F00045-06-000-02'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD16,000 Deductible*',
#     'HKD25,000 Deductible*',
#     'HKD50,000 Deductible*',
#     'HKD100,000 Deductible*',
#     'HKD250,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00070-01-000-01',
#     'F00070-02-000-01',
#     'F00070-03-000-01',
#     'F00070-04-000-01',
#     'F00070-05-000-01',
#     'F00070-06-000-01',
#     'F00070-07-000-01',
#     'F00070-08-000-01',
#     'F00070-09-000-01',
#     'F00070-10-000-01',
#     'F00070-11-000-01',
#     'F00070-12-000-01'],
#    'ward_level': ['Standard (HKD0 Deductible)*',
#     'Standard (HKD16,000 Deductible)*',
#     'Standard (HKD25,000 Deductible)*',
#     'Standard (HKD50,000 Deductible)*',
#     'Standard (HKD100,000 Deductible)*',
#     'Standard (HKD250,000 Deductible)*',
#     'Superior (HKD0 Deductible)*',
#     'Superior (HKD16,000 Deductible)*',
#     'Superior (HKD25,000 Deductible)*',
#     'Superior (HKD50,000 Deductible)*',
#     'Superior (HKD100,000 Deductible)*',
#     'Superior (HKD250,000 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00067-01-000-01',
#     'F00067-02-000-01',
#     'F00067-03-000-01',
#     'F00067-04-000-01',
#     'F00067-05-000-01',
#     'F00067-06-000-01',
#     'F00067-07-000-01',
#     'F00067-08-000-01',
#     'F00067-09-000-01',
#     'F00067-10-000-01',
#     'F00067-11-000-01',
#     'F00067-12-000-01',
#     'F00067-13-000-01',
#     'F00067-14-000-01',
#     'F00067-15-000-01',
#     'F00067-16-000-01',
#     'F00067-17-000-01',
#     'F00067-18-000-01',
#     'F00067-19-000-01',
#     'F00067-20-000-01',
#     'F00067-21-000-01',
#     'F00067-22-000-01',
#     'F00067-23-000-01',
#     'F00067-24-000-01'],
#    'ward_level': ['Standard (HKD0 Deductible)*',
#     'Standard (HKD25,000 Deductible)*',
#     'Standard (HKD40,000 Deductible)*',
#     'Standard (HKD80,000 Deductible)*',
#     'Standard (HKD120,000 Deductible)*',
#     'Standard (HKD250,000 Deductible)*',
#     'Standard Plus (HKD0 Deductible)*',
#     'Standard Plus (HKD25,000 Deductible)*',
#     'Standard Plus (HKD40,000 Deductible)*',
#     'Standard Plus (HKD80,000 Deductible)*',
#     'Standard Plus (HKD120,000 Deductible)*',
#     'Standard Plus (HKD250,000 Deductible)*',
#     'Superior (HKD0 Deductible)*',
#     'Superior (HKD25,000 Deductible)*',
#     'Superior (HKD40,000 Deductible)*',
#     'Superior (HKD80,000 Deductible)*',
#     'Superior (HKD120,000 Deductible)*',
#     'Superior (HKD250,000 Deductible)*',
#     'Premier (HKD0 Deductible)*',
#     'Premier (HKD25,000 Deductible)*',
#     'Premier (HKD40,000 Deductible)*',
#     'Premier (HKD80,000 Deductible)*',
#     'Premier (HKD120,000 Deductible)*',
#     'Premier (HKD250,000 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00039-01-000-02',
#     'F00039-01-001-02',
#     'F00039-02-000-02',
#     'F00039-02-001-02',
#     'F00039-03-000-02',
#     'F00039-03-001-02'],
#    'ward_level': ['Plan I*',
#     'Plan I with SMM*',
#     'Plan II*',
#     'Plan II with SMM*',
#     'Plan III*',
#     'Plan III with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00049-01-000-02',
#     'F00049-02-000-02',
#     'F00049-03-000-02',
#     'F00049-04-000-02',
#     'F00049-05-000-02',
#     'F00049-06-000-02',
#     'F00049-07-000-02',
#     'F00049-08-000-02',
#     'F00049-09-000-02',
#     'F00049-10-000-02',
#     'F00049-11-000-02',
#     'F00049-12-000-02',
#     'F00049-13-000-02',
#     'F00049-14-000-02',
#     'F00049-15-000-02',
#     'F00049-16-000-02'],
#    'ward_level': ['Bronze level (HKD0 Deductible)*',
#     'Bronze level (HKD16,000 Deductible)*',
#     'Bronze level (HKD50,000 Deductible)*',
#     'Bronze level (HKD100,000 Deductible)*',
#     'Silver level (HKD0 Deductible)*',
#     'Silver level (HKD16,000 Deductible)*',
#     'Silver level (HKD50,000 Deductible)*',
#     'Silver level (HKD100,000 Deductible)*',
#     'Gold level (HKD0 Deductible)*',
#     'Gold level (HKD16,000 Deductible)*',
#     'Gold level (HKD50,000 Deductible)*',
#     'Gold level (HKD100,000 Deductible)*',
#     'Diamond level (HKD0 Deductible)*',
#     'Diamond level (HKD16,000 Deductible)*',
#     'Diamond level (HKD50,000 Deductible)*',
#     'Diamond level (HKD100,000 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00047-01-000-02', 'F00047-01-001-02'],
#    'ward_level': ['Flexi Plan (Classic)*', 'Flexi Plan (Classic with SMM)*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00048-01-000-02', 'F00048-01-001-02'],
#    'ward_level': ['Flexi Plan (Plus)*', 'Flexi Plan (Plus with SMM)*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00046-01-000-02'],
#    'ward_level': ['Flexi Plan (Premium)*'],
#    'plan_premium': ['Standard Premium']},
#   {'cert_no': ['F00019-01-000-03',
#     'F00019-01-001-03',
#     'F00019-01-002-03',
#     'F00019-02-000-03',
#     'F00019-02-001-03',
#     'F00019-02-002-03',
#     'F00019-03-000-03',
#     'F00019-03-001-03',
#     'F00019-03-002-03'],
#    'ward_level': ['Ward*',
#     'Ward with SMM*',
#     'Ward with SMM Plus*',
#     'Semi-private Room*',
#     'Semi-private Room with SMM*',
#     'Semi-private Room with SMM Plus*',
#     'Private Room*',
#     'Private Room with SMM*',
#     'Private Room with SMM Plus*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00071-01-000-01',
#     'F00071-02-000-01',
#     'F00071-03-000-01',
#     'F00071-04-000-01',
#     'F00071-05-000-01',
#     'F00071-06-000-01',
#     'F00071-07-000-01',
#     'F00071-08-000-01',
#     'F00071-09-000-01',
#     'F00071-10-000-01',
#     'F00071-11-000-01',
#     'F00071-12-000-01',
#     'F00071-13-000-01',
#     'F00071-14-000-01',
#     'F00071-15-000-01',
#     'F00071-16-000-01'],
#    'ward_level': ['Advance (HKD0 Deductible)*',
#     'Advance (HKD25,000 Deductible)*',
#     'Advance (HKD50,000 Deductible)*',
#     'Advance (HKD100,000 Deductible)*',
#     'Advance (USD0 Deductible)*',
#     'Advance (USD3,125 Deductible)*',
#     'Advance (USD6,250 Deductible)*',
#     'Advance (USD12,500 Deductible)*',
#     'Smart (HKD0 Deductible)*',
#     'Smart (HKD25,000 Deductible)*',
#     'Smart (HKD50,000 Deductible)*',
#     'Smart (HKD100,000 Deductible)*',
#     'Smart (USD0 Deductible)*',
#     'Smart (USD3,125 Deductible)*',
#     'Smart (USD6,250 Deductible)*',
#     'Smart (USD12,500 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00041-01-000-04',
#     'F00041-02-000-04',
#     'F00041-03-000-04',
#     'F00041-04-000-02',
#     'F00041-05-000-01',
#     'F00041-06-000-01',
#     'F00041-07-000-01',
#     'F00041-08-000-01',
#     'F00041-09-000-01'],
#    'ward_level': ['Advance (HKD0 Deductible)*',
#     'Advance (HKD8,000 Deductible)*',
#     'Advance (HKD22,800 Deductible)*',
#     'Advance (HKD45,000 Deductible)*',
#     'Advance (HKD100,000 Deductible)*',
#     'Smart (HKD0 Deductible)*',
#     'Smart (HKD22,800 Deductible)*',
#     'Smart (HKD45,000 Deductible)*',
#     'Smart (HKD100,000 Deductible)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00023-01-000-02',
#     'F00023-01-001-02',
#     'F00023-02-000-02',
#     'F00023-02-001-02',
#     'F00023-03-000-02',
#     'F00023-03-001-02'],
#    'ward_level': ['Plan A*',
#     'Plan A with SMM*',
#     'Plan B*',
#     'Plan B with SMM*',
#     'Plan C*',
#     'Plan C with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00013-01-000-05',
#     'F00013-01-001-05',
#     'F00013-01-002-05',
#     'F00013-02-000-05',
#     'F00013-02-001-05',
#     'F00013-02-002-05',
#     'F00013-03-000-05',
#     'F00013-03-001-05',
#     'F00013-04-000-05',
#     'F00013-04-001-05',
#     'F00013-04-002-05',
#     'F00013-05-000-05',
#     'F00013-05-001-05',
#     'F00013-05-002-05',
#     'F00013-06-000-05',
#     'F00013-06-001-05'],
#    'ward_level': ['Ward (HKD)*',
#     'Ward with SMM 1 (HKD)*',
#     'Ward with SMM 2 (HKD)*',
#     'Semi-private Room (HKD)*',
#     'Semi-private Room with SMM 1 (HKD)*',
#     'Semi-private Room with SMM 2 (HKD)*',
#     'Private Room (HKD)*',
#     'Private Room with SMM (HKD)*',
#     'Ward (USD)*',
#     'Ward with SMM 1 (USD)*',
#     'Ward with SMM 2 (USD)*',
#     'Semi-private Room (USD)*',
#     'Semi-private Room with SMM 1 (USD)*',
#     'Semi-private Room with SMM 2 (USD)*',
#     'Private Room (USD)*',
#     'Private Room with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00068-01-000-01',
#     'F00068-02-000-01',
#     'F00068-03-000-01',
#     'F00068-04-000-01',
#     'F00068-05-000-01',
#     'F00068-06-000-01'],
#    'ward_level': ['Ward with SMM (HKD)*',
#     'Semi-private Room with SMM (HKD)*',
#     'Private Room with SMM (HKD)*',
#     'Ward with SMM (USD)*',
#     'Semi-private Room with SMM (USD)*',
#     'Private Room with SMM (USD)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00050-01-000-04',
#     'F00050-02-000-04',
#     'F00050-03-000-04',
#     'F00050-04-000-04',
#     'F00050-05-000-04',
#     'F00050-06-000-04',
#     'F00050-07-000-01',
#     'F00050-08-000-01',
#     'F00050-09-000-01',
#     'F00050-10-000-01',
#     'F00050-11-000-01',
#     'F00050-12-000-01',
#     'F00050-13-000-01',
#     'F00050-14-000-01',
#     'F00050-15-000-01',
#     'F00050-16-000-01'],
#    'ward_level': ['HKD0 Deductible (Asia)*',
#     'HKD20,000 Deductible (Asia)*',
#     'HKD50,000 Deductible (Asia)*',
#     'USD0 Deductible (Asia)*',
#     'USD2,500 Deductible (Asia)*',
#     'USD6,250 Deductible (Asia)*',
#     'HKD96,000 Deductible (Asia)*',
#     'USD12,000 Deductible (Asia)*',
#     'HKD0 Deductible (Worldwide except USA)*',
#     'HKD20,000 Deductible (Worldwide except USA)*',
#     'HKD50,000 Deductible (Worldwide except USA)*',
#     'HKD96,000 Deductible (Worldwide except USA)*',
#     'USD0 Deductible (Worldwide except USA)*',
#     'USD2,500 Deductible (Worldwide except USA)*',
#     'USD6,250 Deductible (Worldwide except USA)*',
#     'USD12,000 Deductible (Worldwide except USA)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00026-01-000-02', 'F00026-01-001-02'],
#    'ward_level': ['Scheme 1*', 'Scheme 2*'],
#    'plan_premium': ['Standard Premium', 'Standard Premium']},
#   {'cert_no': ['F00066-01-000-01',
#     'F00066-02-000-01',
#     'F00066-03-000-01',
#     'F00066-04-000-01'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD20,000 Deductible*',
#     'HKD50,000 Deductible*',
#     'HKD80,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00063-01-000-01',
#     'F00063-02-000-01',
#     'F00063-03-000-01',
#     'F00063-04-000-01'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD20,000 Deductible*',
#     'HKD50,000 Deductible*',
#     'HKD80,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00042-01-000-02', 'F00042-02-000-02', 'F00042-03-000-02'],
#    'ward_level': ['Ward*', 'Semi-Private*', 'Standard Private*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00020-01-000-03',
#     'F00020-01-001-03',
#     'F00020-02-000-03',
#     'F00020-02-001-03',
#     'F00020-03-000-03',
#     'F00020-03-001-03',
#     'F00020-04-000-03',
#     'F00020-04-001-03',
#     'F00020-05-000-01',
#     'F00020-05-001-01'],
#    'ward_level': ['Plan 1*',
#     'Plan 1M*',
#     'Plan 2*',
#     'Plan 2M*',
#     'Plan 3*',
#     'Plan 3M*',
#     'Plan 4*',
#     'Plan 4M*',
#     'Plan X*',
#     'Plan XM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00065-01-000-01',
#     'F00065-02-000-01',
#     'F00065-03-000-01',
#     'F00065-04-000-01'],
#    'ward_level': ['HKD0 Deductible*',
#     'HKD15,000 Deductible*',
#     'HKD30,000 Deductible*',
#     'HKD100,000 Deductible*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00036-01-000-02',
#     'F00036-02-000-02',
#     'F00036-03-000-02',
#     'F00036-04-000-02',
#     'F00036-05-000-02',
#     'F00036-06-000-02',
#     'F00036-07-000-02',
#     'F00036-08-000-02'],
#    'ward_level': ['HKD0 Deductible (Asia)*',
#     'HKD60,000 Deductible (Asia)*',
#     'HKD90,000 Deductible (Asia)*',
#     'HKD150,000 Deductible (Asia)*',
#     'HKD0 Deductible (Worldwide excluding the U.S.)*',
#     'HKD60,000 Deductible (Worldwide excluding the U.S.)*',
#     'HKD90,000 Deductible (Worldwide excluding the U.S.)*',
#     'HKD150,000 Deductible (Worldwide excluding the U.S.)*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']},
#   {'cert_no': ['F00044-01-000-02',
#     'F00044-01-001-02',
#     'F00044-02-000-02',
#     'F00044-02-001-02'],
#    'ward_level': ['Essential*',
#     'Essential with SMM*',
#     'Advanced*',
#     'Advanced with SMM*'],
#    'plan_premium': ['Standard Premium',
#     'Standard Premium',
#     'Standard Premium',
#     'Standard Premium']}]}

# %%
df= pd.json_normalize(data, 
                   data['plan']['plan_name'],
                   data['plan']['insurer'],
                   data['plan']['effective_date'],
                   data['plan']['earliest_date'],
                #    data['certifications'],
                   errors= 'ignore'
                   )

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df= pd.json_normalize(data,
#       2                    data['plan']['plan_name'],
#       3                    data['plan']['insurer'],
#       4                    data['plan']['effective_date'],
#       5                    data['plan']['earliest_date'],
#       6                 #    data['certifications'],
#       7                    errors= 'ignore'
#       8                    )
#      10 df
#
# File c:\Users\shuto\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# File c:\Users\shuto\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_normalize.py:496, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     493             if level + 1 == len(val):
#     494                 seen_meta[key] = _pull_field(obj, val[-1])
# --> 496         _recursive_extract(obj[path[0]], path[1:], seen_meta, level=level + 1)
#     497 else:
#     498     for obj in data:
#
# KeyError: 'AIA Voluntary Health Insurance Flexi Scheme'

# %%
data['certifications']
# Out:
# [{'cert_no': ['F00022-01-000-03',
#    'F00022-02-000-03',
#    'F00022-03-000-03',
#    'F00022-04-000-03',
#    'F00022-05-000-03',
#    'F00022-06-000-03'],
#   'ward_level': ['Ward (HKD)*',
#    'Semi-private (HKD)*',
#    'Standard Private (HKD)*',
#    'Ward (USD)*',
#    'Semi-private (USD)*',
#    'Standard Private (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00025-01-000-03',
#    'F00025-02-000-03',
#    'F00025-03-000-03',
#    'F00025-04-000-03',
#    'F00025-05-000-03',
#    'F00025-06-000-03'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD16,000 Deductible*',
#    'HKD25,000 Deductible*',
#    'USD0 Deductible*',
#    'USD2,000 Deductible*',
#    'USD3,125 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00053-01-000-02',
#    'F00053-02-000-02',
#    'F00053-03-000-02',
#    'F00053-04-000-02',
#    'F00053-05-000-02',
#    'F00053-06-000-02'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD16,000 Deductible*',
#    'HKD25,000 Deductible*',
#    'USD0 Deductible*',
#    'USD2,000 Deductible*',
#    'USD3,125 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00054-01-000-02',
#    'F00054-02-000-02',
#    'F00054-03-000-02',
#    'F00054-04-000-02',
#    'F00054-05-000-02',
#    'F00054-06-000-02'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD16,000 Deductible*',
#    'HKD25,000 Deductible*',
#    'USD0 Deductible*',
#    'USD2,000 Deductible*',
#    'USD3,125 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00074-01-000-01',
#    'F00074-02-000-01',
#    'F00074-03-000-01',
#    'F00074-04-000-01',
#    'F00074-05-000-01',
#    'F00074-06-000-01',
#    'F00074-07-000-01',
#    'F00074-08-000-01',
#    'F00074-09-000-01',
#    'F00074-10-000-01',
#    'F00074-11-000-01',
#    'F00074-12-000-01',
#    'F00074-13-000-01',
#    'F00074-14-000-01',
#    'F00074-15-000-01',
#    'F00074-16-000-01'],
#   'ward_level': ['HKD0 Deductible (Asia)*',
#    'HKD16,000 Deductible (Asia)*',
#    'HKD25,000 Deductible (Asia)*',
#    'HKD50,000 Deductible (Asia)*',
#    'HKD0 Deductible (Worldwide except USA)*',
#    'HKD16,000 Deductible (Worldwide except USA)*',
#    'HKD25,000 Deductible (Worldwide except USA)*',
#    'HKD50,000 Deductible (Worldwide except USA)*',
#    'USD0 Deductible (Asia)*',
#    'USD2,000 Deductible (Asia)*',
#    'USD3,125 Deductible (Asia)*',
#    'USD6,250 Deductible (Asia)*',
#    'USD0 Deductible (Worldwide except USA)*',
#    'USD2,000 Deductible (Worldwide except USA)*',
#    'USD3,125 Deductible (Worldwide except USA)*',
#    'USD6,250 Deductible (Worldwide except USA)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00033-01-000-02',
#    'F00033-01-001-02',
#    'F00033-02-000-02',
#    'F00033-02-001-02'],
#   'ward_level': ['Silver Plan*',
#    'Silver Plan with SMM*',
#    'Gold Plan*',
#    'Gold Plan with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00038-01-000-02', 'F00038-02-000-02'],
#   'ward_level': ['Semi-Private Room*', 'Standard Private Room*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00061-01-000-01',
#    'F00061-01-001-01',
#    'F00061-02-000-01',
#    'F00061-02-001-01',
#    'F00061-02-002-01'],
#   'ward_level': ['Plan 1*',
#    'Plan 1A with SMM*',
#    'Plan 2*',
#    'Plan 2A with SMM*',
#    'Plan 2B with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00034-01-000-04',
#    'F00034-02-000-04',
#    'F00034-03-000-04',
#    'F00034-04-000-04',
#    'F00034-05-000-04',
#    'F00034-06-000-04',
#    'F00034-07-000-04',
#    'F00034-08-000-04',
#    'F00034-09-000-04',
#    'F00034-10-000-04',
#    'F00034-11-000-04',
#    'F00034-12-000-04',
#    'F00034-13-000-04',
#    'F00034-14-000-04',
#    'F00034-15-000-04',
#    'F00034-16-000-04',
#    'F00034-17-000-04',
#    'F00034-18-000-04',
#    'F00034-19-000-02',
#    'F00034-20-000-02',
#    'F00034-21-000-02',
#    'F00034-22-000-02',
#    'F00034-23-000-02',
#    'F00034-24-000-02'],
#   'ward_level': ['Regular (HKD0 Deductible)*',
#    'Regular (HKD20,000 Deductible)*',
#    'Regular (HKD50,000 Deductible)*',
#    'Enhance (HKD0 Deductible)*',
#    'Enhance (HKD20,000 Deductible)*',
#    'Enhance (HKD50,000 Deductible)*',
#    'Premier (HKD0 Deductible)*',
#    'Premier (HKD20,000 Deductible)*',
#    'Premier (HKD50,000 Deductible)*',
#    'Regular (USD0 Deductible)*',
#    'Regular (USD2,500 Deductible)*',
#    'Regular (USD6,250 Deductible)*',
#    'Enhance (USD0 Deductible)*',
#    'Enhance (USD2,500 Deductible)*',
#    'Enhance (USD6,250 Deductible)*',
#    'Premier (USD0 Deductible)*',
#    'Premier (USD2,500 Deductible)*',
#    'Premier (USD6,250 Deductible)*',
#    'Noble (HKD0 Deductible)*',
#    'Noble (HKD20,000 Deductible)*',
#    'Noble (HKD50,000 Deductible)*',
#    'Noble (USD0 Deductible)*',
#    'Noble (USD2,500 Deductible)*',
#    'Noble (USD6,250 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00017-01-000-03',
#    'F00017-01-001-03',
#    'F00017-02-000-03',
#    'F00017-02-001-03',
#    'F00017-03-000-03',
#    'F00017-03-001-03',
#    'F00017-04-000-03',
#    'F00017-04-001-03',
#    'F00017-05-000-03',
#    'F00017-05-001-03',
#    'F00017-06-000-03',
#    'F00017-06-001-03'],
#   'ward_level': ['Regular (HKD)*',
#    'Regular with SMM (HKD)*',
#    'Superior (HKD)*',
#    'Superior with SMM (HKD)*',
#    'Premier (HKD)*',
#    'Premier with SMM (HKD)*',
#    'Regular (USD)*',
#    'Regular with SMM (USD)*',
#    'Superior (USD)*',
#    'Superior with SMM (USD)*',
#    'Premier (USD)*',
#    'Premier with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00018-01-000-03',
#    'F00018-01-001-03',
#    'F00018-02-000-03',
#    'F00018-02-001-03',
#    'F00018-03-000-03',
#    'F00018-03-001-03',
#    'F00018-04-000-03',
#    'F00018-04-001-03',
#    'F00018-05-000-03',
#    'F00018-05-001-03',
#    'F00018-06-000-03',
#    'F00018-06-001-03'],
#   'ward_level': ['Regular (HKD)*',
#    'Regular with SMM (HKD)*',
#    'Superior (HKD)*',
#    'Superior with SMM (HKD)*',
#    'Premier (HKD)*',
#    'Premier with SMM (HKD)*',
#    'Regular (USD)*',
#    'Regular with SMM (USD)*',
#    'Superior (USD)*',
#    'Superior with SMM (USD)*',
#    'Premier (USD)*',
#    'Premier with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00028-01-000-02',
#    'F00028-01-001-02',
#    'F00028-01-002-02',
#    'F00028-01-003-02',
#    'F00028-01-004-02',
#    'F00028-01-005-02',
#    'F00028-01-006-02',
#    'F00028-01-007-02'],
#   'ward_level': ['Basic plan*',
#    'Basic plan with upgraded benefits 1*',
#    'Basic plan with upgraded benefits 2*',
#    'Basic plan with upgraded benefits 3*',
#    'Basic plan with SMM*',
#    'Basic plan with SMM & upgraded benefits 1*',
#    'Basic plan with SMM & upgraded benefits 2*',
#    'Basic plan with SMM & upgraded benefits 3*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00059-01-000-01',
#    'F00059-02-000-01',
#    'F00059-03-000-01',
#    'F00059-04-000-01',
#    'F00059-05-000-01',
#    'F00059-06-000-01',
#    'F00059-07-000-01',
#    'F00059-08-000-01'],
#   'ward_level': ['HKD0 Deductible (Asia & Australia-New Zealand)*',
#    'HKD20,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD40,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD80,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD0 Deductible (Worldwide )*',
#    'HKD20,000 Deductible (Worldwide )*',
#    'HKD40,000 Deductible (Worldwide )*',
#    'HKD80,000 Deductible (Worldwide )*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00073-01-000-01',
#    'F00073-02-000-01',
#    'F00073-03-000-01',
#    'F00073-04-000-01',
#    'F00073-05-000-01',
#    'F00073-06-000-01',
#    'F00073-07-000-01',
#    'F00073-08-000-01'],
#   'ward_level': ['HKD0 Deductible (Asia & Australia-New Zealand)*',
#    'HKD20,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD40,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD80,000 Deductible (Asia & Australia-New Zealand)*',
#    'HKD0 Deductible (Worldwide )*',
#    'HKD20,000 Deductible (Worldwide )*',
#    'HKD40,000 Deductible (Worldwide )*',
#    'HKD80,000 Deductible (Worldwide )*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00014-01-000-02'],
#   'ward_level': ['CareForYou*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00043-01-000-02',
#    'F00043-01-001-02',
#    'F00043-01-002-02',
#    'F00043-02-000-02',
#    'F00043-02-001-02',
#    'F00043-02-002-02',
#    'F00043-03-000-02',
#    'F00043-03-001-02',
#    'F00043-03-002-02',
#    'F00043-04-000-02'],
#   'ward_level': ['Plan A*',
#    'Plan A with SMM (No Coinsurance)*',
#    'Plan A with SMM (with 20% Coinsurance)*',
#    'Plan B*',
#    'Plan B with SMM (No Coinsurance)*',
#    'Plan B with SMM (with 20% Coinsurance)*',
#    'Plan C*',
#    'Plan C with SMM (No Coinsurance)*',
#    'Plan C with SMM (with 20% Coinsurance)*',
#    'Plan D with SMM (with 20% Coinsurance)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00057-01-000-02',
#    'F00057-02-000-02',
#    'F00057-03-000-02',
#    'F00057-04-000-02'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD10,000 Deductible*',
#    'HKD30,000 Deductible*',
#    'HKD70,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00060-01-000-04',
#    'F00060-02-000-04',
#    'F00060-03-000-04',
#    'F00060-04-000-04',
#    'F00060-05-000-04',
#    'F00060-06-000-04',
#    'F00060-07-000-04',
#    'F00060-08-000-04',
#    'F00060-09-000-01',
#    'F00060-10-000-01',
#    'F00060-11-000-01',
#    'F00060-12-000-01'],
#   'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#    'Semi-Private Room - HKD20,000 Deductible*',
#    'Semi-Private Room - HKD50,000 Deductible*',
#    'Semi-Private Room - HKD80,000 Deductible*',
#    'Private Room - HKD0 Deductible*',
#    'Private Room - HKD20,000 Deductible*',
#    'Private Room - HKD50,000 Deductible*',
#    'Private Room - HKD80,000 Deductible*',
#    'Ward Room - HKD0 Deductible*',
#    'Ward Room - HKD20,000 Deductible*',
#    'Ward Room - HKD50,000 Deductible*',
#    'Ward Room - HKD80,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00031-01-000-05', 'F00031-02-000-05'],
#   'ward_level': ['Regular*', 'Plus*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00040-01-000-03',
#    'F00040-02-000-03',
#    'F00040-03-000-03',
#    'F00040-04-000-03',
#    'F00040-05-000-03',
#    'F00040-06-000-03',
#    'F00040-07-000-03',
#    'F00040-08-000-03',
#    'F00040-09-000-01',
#    'F00040-10-000-01',
#    'F00040-11-000-01',
#    'F00040-12-000-01',
#    'F00040-13-000-01',
#    'F00040-14-000-01',
#    'F00040-15-000-01',
#    'F00040-16-000-01'],
#   'ward_level': ['Advance (HKD0 Deductible)*',
#    'Advance (HKD12,000 Deductible)*',
#    'Advance (HKD40,000 Deductible)*',
#    'Advance (HKD80,000 Deductible)*',
#    'Deluxe (HKD0 Deductible)*',
#    'Deluxe (HKD12,000 Deductible)*',
#    'Deluxe (HKD40,000 Deductible)*',
#    'Deluxe (HKD80,000 Deductible)*',
#    'Advance Pro (HKD0 Deductible)*',
#    'Advance Pro (HKD12,000 Deductible)*',
#    'Advance Pro (HKD40,000 Deductible)*',
#    'Advance Pro (HKD80,000 Deductible)*',
#    'Deluxe Pro (HKD0 Deductible)*',
#    'Deluxe Pro (HKD12,000 Deductible)*',
#    'Deluxe Pro (HKD40,000 Deductible)*',
#    'Deluxe Pro (HKD80,000 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00029-01-000-05',
#    'F00029-01-001-05',
#    'F00029-02-000-05',
#    'F00029-02-001-05',
#    'F00029-03-000-05',
#    'F00029-03-001-05'],
#   'ward_level': ['Standard*',
#    'Standard Plus*',
#    'Advance*',
#    'Advance Plus*',
#    'Deluxe*',
#    'Deluxe Plus*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00035-01-000-04',
#    'F00035-02-000-04',
#    'F00035-03-000-04',
#    'F00035-04-000-04'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD12,000 Deductible*',
#    'HKD40,000 Deductible*',
#    'HKD80,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00024-01-000-02'],
#   'ward_level': ['Healthy Life Medical Insurance Plan*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00030-01-000-02',
#    'F00030-01-001-02',
#    'F00030-02-000-02',
#    'F00030-02-001-02'],
#   'ward_level': ['Semi-private*',
#    'Semi-private with SMM*',
#    'Private*',
#    'Private with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00052-01-000-01',
#    'F00052-02-000-01',
#    'F00052-02-001-01',
#    'F00052-03-000-01',
#    'F00052-03-001-01'],
#   'ward_level': ['Plan 1 - Ward with SMM*',
#    'Plan 2 - Semi-Private Room*',
#    'Plan 3 - Semi-Private Room with SMM*',
#    'Plan 4 - Standard Private Room*',
#    'Plan 5 - Standard Private Room with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00062-01-000-02',
#    'F00062-02-000-02',
#    'F00062-03-000-02',
#    'F00062-04-000-02',
#    'F00062-05-000-02',
#    'F00062-06-000-02'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD20,000 Deductible*',
#    'HKD50,000 Deductible*',
#    'USD0 Deductible*',
#    'USD2,500 Deductible*',
#    'USD6,250 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00027-01-000-03',
#    'F00027-01-001-03',
#    'F00027-02-000-03',
#    'F00027-02-001-03',
#    'F00027-03-000-03',
#    'F00027-03-001-03',
#    'F00027-04-000-03',
#    'F00027-04-001-03',
#    'F00027-05-000-03',
#    'F00027-05-001-03',
#    'F00027-06-000-03',
#    'F00027-06-001-03',
#    'F00027-07-000-03',
#    'F00027-07-001-03',
#    'F00027-08-000-03',
#    'F00027-08-001-03'],
#   'ward_level': ['Classic (HKD)*',
#    'Classic with Top-up benefit (HKD)*',
#    'Ward (HKD)*',
#    'Ward with Top-up benefit (HKD)*',
#    'Semi-Private (HKD)*',
#    'Semi-Private with Top-up benefit (HKD)*',
#    'Private (HKD)*',
#    'Private with Top-up benefit (HKD)*',
#    'Classic (USD)*',
#    'Classic with Top-up benefit (USD)*',
#    'Ward (USD)*',
#    'Ward with Top-up benefit (USD)*',
#    'Semi-Private (USD)*',
#    'Semi-Private with Top-up benefit (USD)*',
#    'Private (USD)*',
#    'Private with Top-up benefit (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00075-01-000-01',
#    'F00075-02-000-01',
#    'F00075-03-000-01',
#    'F00075-04-000-01',
#    'F00075-05-000-01',
#    'F00075-06-000-01',
#    'F00075-07-000-01',
#    'F00075-08-000-01',
#    'F00075-09-000-01',
#    'F00075-10-000-01'],
#   'ward_level': ['HKD0 Deductible (Asia)*',
#    'HKD25,000 Deductible (Asia)*',
#    'HKD50,000 Deductible (Asia)*',
#    'HKD100,000 Deductible (Asia)*',
#    'HKD150,000 Deductible (Asia)*',
#    'HKD0 Deductible (Worldwide excluding USA)*',
#    'HKD25,000 Deductible (Worldwide excluding USA)*',
#    'HKD50,000 Deductible (Worldwide excluding USA)*',
#    'HKD100,000 Deductible (Worldwide excluding USA)*',
#    'HKD150,000 Deductible (Worldwide excluding USA)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00055-01-000-02'],
#   'ward_level': ['Flexi Plan SMM*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00056-01-000-03',
#    'F00056-02-000-03',
#    'F00056-03-000-03',
#    'F00056-04-000-03',
#    'F00056-05-000-03',
#    'F00056-06-000-02',
#    'F00056-07-000-02',
#    'F00056-08-000-02'],
#   'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#    'Semi-Private Room - HKD15,000 Deductible*',
#    'Semi-Private Room - HKD25,000 Deductible*',
#    'Semi-Private Room - HKD50,000 Deductible*',
#    'Semi-Private Room - HKD75,000 Deductible*',
#    'Standard Ward - HKD0 Deductible*',
#    'Standard Ward - HKD15,000 Deductible*',
#    'Standard Ward - HKD25,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00012-01-000-03'],
#   'ward_level': ['Flexi Plan SMM*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00016-01-000-04',
#    'F00016-02-000-04',
#    'F00016-03-000-04',
#    'F00016-04-000-04',
#    'F00016-05-000-03',
#    'F00016-06-000-02',
#    'F00016-07-000-02',
#    'F00016-08-000-02'],
#   'ward_level': ['Semi-Private Room - HKD0 Deductible*',
#    'Semi-Private Room - HKD15,000 Deductible*',
#    'Semi-Private Room - HKD25,000 Deductible*',
#    'Semi-Private Room - HKD50,000 Deductible*',
#    'Semi-Private Room - HKD75,000 Deductible*',
#    'Standard Ward - HKD0 Deductible*',
#    'Standard Ward - HKD15,000 Deductible*',
#    'Standard Ward - HKD25,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00021-01-000-02',
#    'F00021-02-000-02',
#    'F00021-03-000-02',
#    'F00021-04-000-02',
#    'F00021-05-000-02',
#    'F00021-06-000-02'],
#   'ward_level': ['Benefit Level 1 with SMM (HKD)*',
#    'Benefit Level 2 with SMM (HKD)*',
#    'Benefit Level 3 with SMM (HKD)*',
#    'Benefit Level 1 with SMM (USD)*',
#    'Benefit Level 2 with SMM (USD)*',
#    'Benefit Level 3 with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00064-01-000-01',
#    'F00064-02-000-01',
#    'F00064-03-000-01',
#    'F00064-04-000-01'],
#   'ward_level': ['Benefit Level 1 (HKD)*',
#    'Benefit Level 2 (HKD)*',
#    'Benefit Level 1 (USD)*',
#    'Benefit Level 2 (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00037-01-000-02',
#    'F00037-02-000-02',
#    'F00037-03-000-02',
#    'F00037-04-000-02',
#    'F00037-05-000-02',
#    'F00037-06-000-02',
#    'F00037-07-000-02',
#    'F00037-08-000-02'],
#   'ward_level': ['Benefit Level 1 with SMM (HKD)*',
#    'Benefit Level 2 with SMM (HKD)*',
#    'Benefit Level 3 with SMM (HKD)*',
#    'Benefit Level 4 with SMM (HKD)*',
#    'Benefit Level 1 with SMM (USD)*',
#    'Benefit Level 2 with SMM (USD)*',
#    'Benefit Level 3 with SMM (USD)*',
#    'Benefit Level 4 with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00069-01-000-01',
#    'F00069-02-000-01',
#    'F00069-03-000-01',
#    'F00069-04-000-01',
#    'F00069-05-000-01',
#    'F00069-06-000-01'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD16,000 Deductible*',
#    'HKD25,000 Deductible*',
#    'HKD50,000 Deductible*',
#    'HKD100,000 Deductible*',
#    'HKD180,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00051-01-000-02', 'F00051-02-000-02'],
#   'ward_level': ['Standard*', 'Superior*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00015-01-000-02'],
#   'ward_level': ['vCare Medical Plan*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00032-01-000-04'],
#   'ward_level': ['vCare Supreme Medical Plan*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00072-01-000-01'],
#   'ward_level': ['Standard*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00045-01-000-04',
#    'F00045-02-000-04',
#    'F00045-03-000-04',
#    'F00045-04-000-04',
#    'F00045-05-000-02',
#    'F00045-06-000-02'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD16,000 Deductible*',
#    'HKD25,000 Deductible*',
#    'HKD50,000 Deductible*',
#    'HKD100,000 Deductible*',
#    'HKD250,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00070-01-000-01',
#    'F00070-02-000-01',
#    'F00070-03-000-01',
#    'F00070-04-000-01',
#    'F00070-05-000-01',
#    'F00070-06-000-01',
#    'F00070-07-000-01',
#    'F00070-08-000-01',
#    'F00070-09-000-01',
#    'F00070-10-000-01',
#    'F00070-11-000-01',
#    'F00070-12-000-01'],
#   'ward_level': ['Standard (HKD0 Deductible)*',
#    'Standard (HKD16,000 Deductible)*',
#    'Standard (HKD25,000 Deductible)*',
#    'Standard (HKD50,000 Deductible)*',
#    'Standard (HKD100,000 Deductible)*',
#    'Standard (HKD250,000 Deductible)*',
#    'Superior (HKD0 Deductible)*',
#    'Superior (HKD16,000 Deductible)*',
#    'Superior (HKD25,000 Deductible)*',
#    'Superior (HKD50,000 Deductible)*',
#    'Superior (HKD100,000 Deductible)*',
#    'Superior (HKD250,000 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00067-01-000-01',
#    'F00067-02-000-01',
#    'F00067-03-000-01',
#    'F00067-04-000-01',
#    'F00067-05-000-01',
#    'F00067-06-000-01',
#    'F00067-07-000-01',
#    'F00067-08-000-01',
#    'F00067-09-000-01',
#    'F00067-10-000-01',
#    'F00067-11-000-01',
#    'F00067-12-000-01',
#    'F00067-13-000-01',
#    'F00067-14-000-01',
#    'F00067-15-000-01',
#    'F00067-16-000-01',
#    'F00067-17-000-01',
#    'F00067-18-000-01',
#    'F00067-19-000-01',
#    'F00067-20-000-01',
#    'F00067-21-000-01',
#    'F00067-22-000-01',
#    'F00067-23-000-01',
#    'F00067-24-000-01'],
#   'ward_level': ['Standard (HKD0 Deductible)*',
#    'Standard (HKD25,000 Deductible)*',
#    'Standard (HKD40,000 Deductible)*',
#    'Standard (HKD80,000 Deductible)*',
#    'Standard (HKD120,000 Deductible)*',
#    'Standard (HKD250,000 Deductible)*',
#    'Standard Plus (HKD0 Deductible)*',
#    'Standard Plus (HKD25,000 Deductible)*',
#    'Standard Plus (HKD40,000 Deductible)*',
#    'Standard Plus (HKD80,000 Deductible)*',
#    'Standard Plus (HKD120,000 Deductible)*',
#    'Standard Plus (HKD250,000 Deductible)*',
#    'Superior (HKD0 Deductible)*',
#    'Superior (HKD25,000 Deductible)*',
#    'Superior (HKD40,000 Deductible)*',
#    'Superior (HKD80,000 Deductible)*',
#    'Superior (HKD120,000 Deductible)*',
#    'Superior (HKD250,000 Deductible)*',
#    'Premier (HKD0 Deductible)*',
#    'Premier (HKD25,000 Deductible)*',
#    'Premier (HKD40,000 Deductible)*',
#    'Premier (HKD80,000 Deductible)*',
#    'Premier (HKD120,000 Deductible)*',
#    'Premier (HKD250,000 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00039-01-000-02',
#    'F00039-01-001-02',
#    'F00039-02-000-02',
#    'F00039-02-001-02',
#    'F00039-03-000-02',
#    'F00039-03-001-02'],
#   'ward_level': ['Plan I*',
#    'Plan I with SMM*',
#    'Plan II*',
#    'Plan II with SMM*',
#    'Plan III*',
#    'Plan III with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00049-01-000-02',
#    'F00049-02-000-02',
#    'F00049-03-000-02',
#    'F00049-04-000-02',
#    'F00049-05-000-02',
#    'F00049-06-000-02',
#    'F00049-07-000-02',
#    'F00049-08-000-02',
#    'F00049-09-000-02',
#    'F00049-10-000-02',
#    'F00049-11-000-02',
#    'F00049-12-000-02',
#    'F00049-13-000-02',
#    'F00049-14-000-02',
#    'F00049-15-000-02',
#    'F00049-16-000-02'],
#   'ward_level': ['Bronze level (HKD0 Deductible)*',
#    'Bronze level (HKD16,000 Deductible)*',
#    'Bronze level (HKD50,000 Deductible)*',
#    'Bronze level (HKD100,000 Deductible)*',
#    'Silver level (HKD0 Deductible)*',
#    'Silver level (HKD16,000 Deductible)*',
#    'Silver level (HKD50,000 Deductible)*',
#    'Silver level (HKD100,000 Deductible)*',
#    'Gold level (HKD0 Deductible)*',
#    'Gold level (HKD16,000 Deductible)*',
#    'Gold level (HKD50,000 Deductible)*',
#    'Gold level (HKD100,000 Deductible)*',
#    'Diamond level (HKD0 Deductible)*',
#    'Diamond level (HKD16,000 Deductible)*',
#    'Diamond level (HKD50,000 Deductible)*',
#    'Diamond level (HKD100,000 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00047-01-000-02', 'F00047-01-001-02'],
#   'ward_level': ['Flexi Plan (Classic)*', 'Flexi Plan (Classic with SMM)*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00048-01-000-02', 'F00048-01-001-02'],
#   'ward_level': ['Flexi Plan (Plus)*', 'Flexi Plan (Plus with SMM)*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00046-01-000-02'],
#   'ward_level': ['Flexi Plan (Premium)*'],
#   'plan_premium': ['Standard Premium']},
#  {'cert_no': ['F00019-01-000-03',
#    'F00019-01-001-03',
#    'F00019-01-002-03',
#    'F00019-02-000-03',
#    'F00019-02-001-03',
#    'F00019-02-002-03',
#    'F00019-03-000-03',
#    'F00019-03-001-03',
#    'F00019-03-002-03'],
#   'ward_level': ['Ward*',
#    'Ward with SMM*',
#    'Ward with SMM Plus*',
#    'Semi-private Room*',
#    'Semi-private Room with SMM*',
#    'Semi-private Room with SMM Plus*',
#    'Private Room*',
#    'Private Room with SMM*',
#    'Private Room with SMM Plus*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00071-01-000-01',
#    'F00071-02-000-01',
#    'F00071-03-000-01',
#    'F00071-04-000-01',
#    'F00071-05-000-01',
#    'F00071-06-000-01',
#    'F00071-07-000-01',
#    'F00071-08-000-01',
#    'F00071-09-000-01',
#    'F00071-10-000-01',
#    'F00071-11-000-01',
#    'F00071-12-000-01',
#    'F00071-13-000-01',
#    'F00071-14-000-01',
#    'F00071-15-000-01',
#    'F00071-16-000-01'],
#   'ward_level': ['Advance (HKD0 Deductible)*',
#    'Advance (HKD25,000 Deductible)*',
#    'Advance (HKD50,000 Deductible)*',
#    'Advance (HKD100,000 Deductible)*',
#    'Advance (USD0 Deductible)*',
#    'Advance (USD3,125 Deductible)*',
#    'Advance (USD6,250 Deductible)*',
#    'Advance (USD12,500 Deductible)*',
#    'Smart (HKD0 Deductible)*',
#    'Smart (HKD25,000 Deductible)*',
#    'Smart (HKD50,000 Deductible)*',
#    'Smart (HKD100,000 Deductible)*',
#    'Smart (USD0 Deductible)*',
#    'Smart (USD3,125 Deductible)*',
#    'Smart (USD6,250 Deductible)*',
#    'Smart (USD12,500 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00041-01-000-04',
#    'F00041-02-000-04',
#    'F00041-03-000-04',
#    'F00041-04-000-02',
#    'F00041-05-000-01',
#    'F00041-06-000-01',
#    'F00041-07-000-01',
#    'F00041-08-000-01',
#    'F00041-09-000-01'],
#   'ward_level': ['Advance (HKD0 Deductible)*',
#    'Advance (HKD8,000 Deductible)*',
#    'Advance (HKD22,800 Deductible)*',
#    'Advance (HKD45,000 Deductible)*',
#    'Advance (HKD100,000 Deductible)*',
#    'Smart (HKD0 Deductible)*',
#    'Smart (HKD22,800 Deductible)*',
#    'Smart (HKD45,000 Deductible)*',
#    'Smart (HKD100,000 Deductible)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00023-01-000-02',
#    'F00023-01-001-02',
#    'F00023-02-000-02',
#    'F00023-02-001-02',
#    'F00023-03-000-02',
#    'F00023-03-001-02'],
#   'ward_level': ['Plan A*',
#    'Plan A with SMM*',
#    'Plan B*',
#    'Plan B with SMM*',
#    'Plan C*',
#    'Plan C with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00013-01-000-05',
#    'F00013-01-001-05',
#    'F00013-01-002-05',
#    'F00013-02-000-05',
#    'F00013-02-001-05',
#    'F00013-02-002-05',
#    'F00013-03-000-05',
#    'F00013-03-001-05',
#    'F00013-04-000-05',
#    'F00013-04-001-05',
#    'F00013-04-002-05',
#    'F00013-05-000-05',
#    'F00013-05-001-05',
#    'F00013-05-002-05',
#    'F00013-06-000-05',
#    'F00013-06-001-05'],
#   'ward_level': ['Ward (HKD)*',
#    'Ward with SMM 1 (HKD)*',
#    'Ward with SMM 2 (HKD)*',
#    'Semi-private Room (HKD)*',
#    'Semi-private Room with SMM 1 (HKD)*',
#    'Semi-private Room with SMM 2 (HKD)*',
#    'Private Room (HKD)*',
#    'Private Room with SMM (HKD)*',
#    'Ward (USD)*',
#    'Ward with SMM 1 (USD)*',
#    'Ward with SMM 2 (USD)*',
#    'Semi-private Room (USD)*',
#    'Semi-private Room with SMM 1 (USD)*',
#    'Semi-private Room with SMM 2 (USD)*',
#    'Private Room (USD)*',
#    'Private Room with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00068-01-000-01',
#    'F00068-02-000-01',
#    'F00068-03-000-01',
#    'F00068-04-000-01',
#    'F00068-05-000-01',
#    'F00068-06-000-01'],
#   'ward_level': ['Ward with SMM (HKD)*',
#    'Semi-private Room with SMM (HKD)*',
#    'Private Room with SMM (HKD)*',
#    'Ward with SMM (USD)*',
#    'Semi-private Room with SMM (USD)*',
#    'Private Room with SMM (USD)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00050-01-000-04',
#    'F00050-02-000-04',
#    'F00050-03-000-04',
#    'F00050-04-000-04',
#    'F00050-05-000-04',
#    'F00050-06-000-04',
#    'F00050-07-000-01',
#    'F00050-08-000-01',
#    'F00050-09-000-01',
#    'F00050-10-000-01',
#    'F00050-11-000-01',
#    'F00050-12-000-01',
#    'F00050-13-000-01',
#    'F00050-14-000-01',
#    'F00050-15-000-01',
#    'F00050-16-000-01'],
#   'ward_level': ['HKD0 Deductible (Asia)*',
#    'HKD20,000 Deductible (Asia)*',
#    'HKD50,000 Deductible (Asia)*',
#    'USD0 Deductible (Asia)*',
#    'USD2,500 Deductible (Asia)*',
#    'USD6,250 Deductible (Asia)*',
#    'HKD96,000 Deductible (Asia)*',
#    'USD12,000 Deductible (Asia)*',
#    'HKD0 Deductible (Worldwide except USA)*',
#    'HKD20,000 Deductible (Worldwide except USA)*',
#    'HKD50,000 Deductible (Worldwide except USA)*',
#    'HKD96,000 Deductible (Worldwide except USA)*',
#    'USD0 Deductible (Worldwide except USA)*',
#    'USD2,500 Deductible (Worldwide except USA)*',
#    'USD6,250 Deductible (Worldwide except USA)*',
#    'USD12,000 Deductible (Worldwide except USA)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00026-01-000-02', 'F00026-01-001-02'],
#   'ward_level': ['Scheme 1*', 'Scheme 2*'],
#   'plan_premium': ['Standard Premium', 'Standard Premium']},
#  {'cert_no': ['F00066-01-000-01',
#    'F00066-02-000-01',
#    'F00066-03-000-01',
#    'F00066-04-000-01'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD20,000 Deductible*',
#    'HKD50,000 Deductible*',
#    'HKD80,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00063-01-000-01',
#    'F00063-02-000-01',
#    'F00063-03-000-01',
#    'F00063-04-000-01'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD20,000 Deductible*',
#    'HKD50,000 Deductible*',
#    'HKD80,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00042-01-000-02', 'F00042-02-000-02', 'F00042-03-000-02'],
#   'ward_level': ['Ward*', 'Semi-Private*', 'Standard Private*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00020-01-000-03',
#    'F00020-01-001-03',
#    'F00020-02-000-03',
#    'F00020-02-001-03',
#    'F00020-03-000-03',
#    'F00020-03-001-03',
#    'F00020-04-000-03',
#    'F00020-04-001-03',
#    'F00020-05-000-01',
#    'F00020-05-001-01'],
#   'ward_level': ['Plan 1*',
#    'Plan 1M*',
#    'Plan 2*',
#    'Plan 2M*',
#    'Plan 3*',
#    'Plan 3M*',
#    'Plan 4*',
#    'Plan 4M*',
#    'Plan X*',
#    'Plan XM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00065-01-000-01',
#    'F00065-02-000-01',
#    'F00065-03-000-01',
#    'F00065-04-000-01'],
#   'ward_level': ['HKD0 Deductible*',
#    'HKD15,000 Deductible*',
#    'HKD30,000 Deductible*',
#    'HKD100,000 Deductible*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00036-01-000-02',
#    'F00036-02-000-02',
#    'F00036-03-000-02',
#    'F00036-04-000-02',
#    'F00036-05-000-02',
#    'F00036-06-000-02',
#    'F00036-07-000-02',
#    'F00036-08-000-02'],
#   'ward_level': ['HKD0 Deductible (Asia)*',
#    'HKD60,000 Deductible (Asia)*',
#    'HKD90,000 Deductible (Asia)*',
#    'HKD150,000 Deductible (Asia)*',
#    'HKD0 Deductible (Worldwide excluding the U.S.)*',
#    'HKD60,000 Deductible (Worldwide excluding the U.S.)*',
#    'HKD90,000 Deductible (Worldwide excluding the U.S.)*',
#    'HKD150,000 Deductible (Worldwide excluding the U.S.)*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']},
#  {'cert_no': ['F00044-01-000-02',
#    'F00044-01-001-02',
#    'F00044-02-000-02',
#    'F00044-02-001-02'],
#   'ward_level': ['Essential*',
#    'Essential with SMM*',
#    'Advanced*',
#    'Advanced with SMM*'],
#   'plan_premium': ['Standard Premium',
#    'Standard Premium',
#    'Standard Premium',
#    'Standard Premium']}]
